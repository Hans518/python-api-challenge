# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#pip install citipy
#pip install openweathermapy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import json
from scipy.stats import linregress

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
cities
# Out:
# ['rikitea',
#  'hithadhoo',
#  'henties bay',
#  'asau',
#  'phayao',
#  'beaverlodge',
#  'dindori',
#  'miraflores',
#  'nanortalik',
#  'kahului',
#  'albany',
#  'itoman',
#  'bambous virieux',
#  'samusu',
#  'hermanus',
#  'tawkar',
#  'salalah',
#  'lebu',
#  'saldanha',
#  'port elizabeth',
#  'busselton',
#  'mataura',
#  'stoyba',
#  'kinkala',
#  'anadyr',
#  'bensonville',
#  'new norfolk',
#  'midland',
#  'hay river',
#  'inuvik',
#  'tiksi',
#  'mrakovo',
#  'port alfred',
#  'rawson',
#  'arraial do cabo',
#  'kharan',
#  'palana',
#  'ponta do sol',
#  'launceston',
#  'punta arenas',
#  'sitka',
#  'grand centre',
#  'boyuibe',
#  'kapaa',
#  'perez',
#  'atuona',
#  'chokurdakh',
#  'benalla',
#  'mayumba',
#  'srednekolymsk',
#  'ulcinj',
#  'kodiak',
#  'hamilton',
#  'hami',
#  'rosiile',
#  'sao sebastiao',
#  'nikolskoye',
#  'osakarovka',
#  'butaritari',
#  'hilo',
#  'saskylakh',
#  'ushuaia',
#  'dikson',
#  'orillia',
#  'colares',
#  'komsomolskiy',
#  'bredasdorp',
#  'lompoc',
#  'rancho palos verdes',
#  'cabo san lucas',
#  'beringovskiy',
#  'bluff',
#  'hasaki',
#  'flinders',
#  'arti',
#  'waipawa',
#  'avarua',
#  'tasiilaq',
#  'yulara',
#  'saint george',
#  'mys shmidta',
#  'mareeba',
#  'esperance',
#  'port moresby',
#  'hambantota',
#  'cidreira',
#  'upernavik',
#  'quarteira',
#  'illoqqortoormiut',
#  'cape town',
#  'lorengau',
#  'bourail',
#  'sao joao da barra',
#  'grindavik',
#  'muros',
#  'codrington',
#  'omsukchan',
#  'xunchang',
#  'laem sing',
#  'bowen',
#  'amderma',
#  'skalistyy',
#  'boende',
#  'simbahan',
#  'talca',
#  'camana',
#  'kenai',
#  'east london',
#  'ambon',
#  'puerto ayora',
#  'isangel',
#  'camopi',
#  'chute-aux-outardes',
#  'geraldton',
#  'pisco',
#  'thompson',
#  'bengkulu',
#  'cumra',
#  'sao filipe',
#  'burnie',
#  'ust-kamchatsk',
#  'quatre cocos',
#  'adamas',
#  'mar del plata',
#  'khonuu',
#  'louis trichardt',
#  'kaitangata',
#  'longyearbyen',
#  'saint-augustin',
#  'klaksvik',
#  'kudahuvadhoo',
#  'mahebourg',
#  'carnarvon',
#  'taolanaro',
#  'bethel',
#  'te anau',
#  'victoria',
#  'yellowknife',
#  'belushya guba',
#  'qaanaaq',
#  'hobart',
#  'georgetown',
#  'dunedin',
#  'barbar',
#  'deputatskiy',
#  'san jeronimo',
#  'tres arroyos',
#  'tuatapere',
#  'narok',
#  'sisimiut',
#  'narsaq',
#  'barra do pirai',
#  'san rafael',
#  'viedma',
#  'pevek',
#  'terrace',
#  'bandarbeyla',
#  'port macquarie',
#  'saleaula',
#  'clyde river',
#  'inhambane',
#  'hualmay',
#  'conde',
#  'shimoda',
#  'gazli',
#  'flagstaff',
#  'kruisfontein',
#  'daud khel',
#  'vaini',
#  'palora',
#  'tura',
#  'port shepstone',
#  'leirvik',
#  'champawat',
#  'bilma',
#  'saint-philippe',
#  'gasa',
#  'toliary',
#  'show low',
#  'macaubas',
#  'valer',
#  'dogondoutchi',
#  'kloulklubed',
#  'jamestown',
#  'chapais',
#  'vardo',
#  'tsihombe',
#  'guerrero negro',
#  'barrow',
#  'lagoa',
#  'ust-nera',
#  'vilyuysk',
#  'port blair',
#  'oranjemund',
#  'teya',
#  'mount vernon',
#  'cherskiy',
#  'oktyabrskiy',
#  'maceio',
#  'husavik',
#  'souillac',
#  'svebolle',
#  'fare',
#  'jose de freitas',
#  'karasjok',
#  'monte escobedo',
#  'sabang',
#  'ribeira grande',
#  'mangrol',
#  'sterling',
#  'novochernorechenskiy',
#  'halalo',
#  'norman wells',
#  'singkang',
#  'xacmaz',
#  'tautira',
#  'timon',
#  'novobiryusinskiy',
#  'dvinskoy',
#  'ngunguru',
#  'leh',
#  'kavieng',
#  'vanimo',
#  'roebourne',
#  'cockburn town',
#  'plettenberg bay',
#  'shizukuishi',
#  'severo-kurilsk',
#  'wasilla',
#  'olavarria',
#  'ola',
#  'vaitupu',
#  'constitucion',
#  'kenmare',
#  'whitehorse',
#  'babanusah',
#  'marcona',
#  'avera',
#  'winnemucca',
#  'torbay',
#  'dolbeau',
#  'paucartambo',
#  'yarada',
#  'peterhead',
#  'yar-sale',
#  'nizhneyansk',
#  'nioro',
#  'tuktoyaktuk',
#  'touros',
#  'taoudenni',
#  'berlevag',
#  'cam ranh',
#  'alyangula',
#  'santiago del estero',
#  'porto novo',
#  'port lincoln',
#  'talnakh',
#  'praia da vitoria',
#  'obluche',
#  'dingzhou',
#  'aksha',
#  'freeport',
#  'smithers',
#  'ixtapa',
#  'castro',
#  'itarema',
#  'mount isa',
#  'luderitz',
#  'quelimane',
#  'tazovskiy',
#  'qingan',
#  'qinggang',
#  'trunovskoye',
#  'san patricio',
#  'kirkwall',
#  'tual',
#  'sarakhs',
#  'san cristobal',
#  'aksu',
#  'were ilu',
#  'starosubkhangulovo',
#  'namibe',
#  'attawapiskat',
#  'orocue',
#  'krasnovka',
#  'alice springs',
#  'fort smith',
#  'nouadhibou',
#  'macamic',
#  'margate',
#  'mindelo',
#  'paradwip',
#  'caconda',
#  'desaguadero',
#  'santiago de cao',
#  'riyadh',
#  'airai',
#  'barentsburg',
#  'grand gaube',
#  'emerald',
#  'nenjiang',
#  'noumea',
#  'byron bay',
#  'rocha',
#  'hudiksvall',
#  'hobyo',
#  'rasshevatskaya',
#  'grand river south east',
#  'kushiro',
#  'merauke',
#  'lithgow',
#  'khatanga',
#  'aksarka',
#  'dasoguz',
#  'yuanping',
#  'ndioum',
#  'jawhar',
#  'severomuysk',
#  'xining',
#  'champasak',
#  'sola',
#  'koumac',
#  'de aar',
#  'vila franca do campo',
#  'katangli',
#  'boyolangu',
#  'bairiki',
#  'hofn',
#  'emba',
#  'eslamshahr',
#  'omboue',
#  'pecangakan',
#  'leningradskiy',
#  'kaka',
#  'broken hill',
#  'dabola',
#  'nhulunbuy',
#  'erenhot',
#  'corrente',
#  'masjed-e soleyman',
#  'salamiyah',
#  'casma',
#  'maloshuyka',
#  'meulaboh',
#  'kuche',
#  'bhag',
#  'penzance',
#  'boguchany',
#  'magadi',
#  'buraydah',
#  'dingle',
#  'bridlington',
#  'verin',
#  'provideniya',
#  'naftah',
#  'sarkand',
#  'qaqortoq',
#  'ondorhaan',
#  'lhokseumawe',
#  'prince rupert',
#  'caravelas',
#  'tumannyy',
#  'gurgan',
#  'flin flon',
#  'matara',
#  'louisbourg',
#  'jiuquan',
#  'richards bay',
#  'antequera',
#  'kankon',
#  'nichinan',
#  'batagay',
#  'portland',
#  'porto santo',
#  'ardalstangen',
#  'progreso',
#  'lolua',
#  'rosaryville',
#  'bilibino',
#  'ratangarh',
#  'port hedland',
#  'severnyy',
#  'togur',
#  'vao',
#  'treinta y tres',
#  'mayskiy',
#  'oranjestad',
#  'jacqueville',
#  'bahia de caraquez',
#  'yeppoon',
#  'kumluca',
#  'sioux lookout',
#  'marawi',
#  'plainview',
#  'nachingwea',
#  'boa vista',
#  'snezhnogorsk',
#  'kirensk',
#  'sergeyevka',
#  'mitu',
#  'polis',
#  'dolinsk',
#  'sao jose da coroa grande',
#  'ratne',
#  'bantou',
#  'baykit',
#  'hurricane',
#  'iquitos',
#  'chuy',
#  'naryan-mar',
#  'sur',
#  'oracon',
#  'mafinga',
#  'darlington',
#  'porto nacional',
#  'port charlotte',
#  'oum hadjer',
#  'svarstad',
#  'westport',
#  'carora',
#  'puerto del rosario',
#  'belmonte',
#  'beloha',
#  'saint anthony',
#  'berdigestyakh',
#  'aykhal',
#  'faanui',
#  'port said',
#  'partyzany',
#  'rock springs',
#  'guajara-mirim',
#  'kamaishi',
#  'wagga wagga',
#  'amapa',
#  'ballina',
#  'baherden',
#  'camacha',
#  'dayong',
#  'valparaiso',
#  'panzhihua',
#  'carbondale',
#  'kemijarvi',
#  'saint-francois',
#  'tiznit',
#  'esslingen',
#  'seit',
#  'biggar',
#  'abu kamal',
#  'tshikapa',
#  'bakchar',
#  'walvis bay',
#  'gorontalo',
#  'vanavara',
#  'luanda',
#  'amarillo',
#  'pangnirtung',
#  'sambava',
#  'lahij',
#  'port-gentil',
#  'yakeshi',
#  'ostrovnoy',
#  'baneh',
#  'thiruvananthapuram',
#  'middlebury',
#  'grobina',
#  'moctezuma',
#  'sakaiminato',
#  'katha',
#  'obanazawa',
#  'severnoye',
#  'dwarka',
#  'aguimes',
#  'pemberton',
#  'kadykchan',
#  'sao borja',
#  'zwedru',
#  'biak',
#  'porbandar',
#  'nome',
#  'arkul',
#  'antalaha',
#  'port hardy',
#  'kalevala',
#  'romny',
#  'tempoal',
#  'araceli',
#  'canico',
#  'soyo',
#  'yankton',
#  'ilulissat',
#  'mundo nuevo',
#  'port-de-paix',
#  'mehamn',
#  'kalamare',
#  'rio gallegos',
#  'saint pete beach',
#  'bubaque',
#  'krasnoyarsk-66',
#  'malakal',
#  'golspie',
#  'nelson bay',
#  'athabasca',
#  'sokoni',
#  'bari sadri',
#  'petropavlovsk-kamchatskiy',
#  'siocon',
#  'tutoia',
#  'deniliquin',
#  'gigmoto',
#  'bathsheba',
#  'basoko',
#  'katsuura',
#  'indian head',
#  'north bend',
#  'severo-yeniseyskiy',
#  'lucapa',
#  'utiroa',
#  'poum',
#  'qui nhon',
#  'ippy',
#  'jak',
#  'turinskaya sloboda',
#  'chara',
#  'yumen',
#  'upington',
#  'saint-pacome',
#  'garoua',
#  'okhotsk',
#  'ulladulla',
#  'mata',
#  'slave lake',
#  'vila velha',
#  'bur gabo',
#  'seoul',
#  'olgod',
#  'le pont-de-claix',
#  'sidi qasim',
#  'presidencia roque saenz pena',
#  'qandala',
#  'phibun mangsahan',
#  'baruun-urt',
#  'cabra',
#  'shingu',
#  'sydney mines',
#  'kavaratti',
#  'coihaique',
#  'frederikshavn',
#  'mokhsogollokh',
#  'olafsvik',
#  'vestmanna',
#  'sentyabrskiy',
#  'guaruja',
#  'menongue',
#  'brae',
#  'naze',
#  'bolshoye sorokino',
#  'egvekinot',
#  'fortuna',
#  'gorgan',
#  'agadir',
#  'paris',
#  'thinadhoo',
#  'road town',
#  'christchurch',
#  'cayenne',
#  'miyazu',
#  'ryde',
#  'mitsamiouli',
#  'novopetrovskoye',
#  'jiddah',
#  'pokhara',
#  'karauzyak',
#  'bonthe',
#  'bitung',
#  'sungaipenuh',
#  'tineo',
#  'bytow',
#  'zyryanka',
#  'tessalit',
#  'north platte',
#  'tampakan',
#  'plaridel',
#  'santarem',
#  'goderich',
#  'lethem',
#  'kalmunai',
#  'coihueco',
#  'ayia galini',
#  'rolim de moura',
#  'harda',
#  'aras',
#  'oksfjord',
#  'kandrian',
#  'freetown',
#  'kandy',
#  'sao miguel do araguaia',
#  'morant bay',
#  'viligili',
#  'bolshiye uki',
#  'trincomalee',
#  'ulaangom',
#  'choa saidan shah',
#  'ancud',
#  'colac',
#  'kawalu']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
response_json = []
city = []
country = []
lat = []
lon = []
weather_list = []
weather = []
temp = []
humidity = []
wind = []
clouds = []
city_count = 0


url = "https://api.openweathermap.org/data/2.5/weather?q="

for x in (cities):
    city_count = city_count + 1
    print(f"Fetching weather data for city {city_count} {x}")
          
    post_response = requests.get(url + x + "&units=imperial&appid=" + api_key).json()
    
    try:
        city.append(post_response['name'])
        country.append(post_response['sys']['country'])
        lat.append(post_response['coord']['lat'])
        lon.append(post_response['coord']['lon'])
        weather.append(post_response['weather'][0]['main'])
        temp.append(post_response['main']['temp'])
        humidity.append(post_response['main']['humidity'])
        wind.append(post_response['wind']['speed'])
        clouds.append(post_response['clouds']['all'])
  
    except KeyError: 
        print("Cannot find city")
# Out:
# Fetching weather data for city 1 rikitea
# Fetching weather data for city 2 hithadhoo
# Fetching weather data for city 3 henties bay
# Fetching weather data for city 4 asau
# Fetching weather data for city 5 phayao
# Fetching weather data for city 6 beaverlodge
# Fetching weather data for city 7 dindori
# Fetching weather data for city 8 miraflores
# Fetching weather data for city 9 nanortalik
# Fetching weather data for city 10 kahului
# Fetching weather data for city 11 albany
# Fetching weather data for city 12 itoman
# Fetching weather data for city 13 bambous virieux
# Fetching weather data for city 14 samusu
# Cannot find city
# Fetching weather data for city 15 hermanus
# Fetching weather data for city 16 tawkar
# Cannot find city
# Fetching weather data for city 17 salalah
# Fetching weather data for city 18 lebu
# Fetching weather data for city 19 saldanha
# Fetching weather data for city 20 port elizabeth
# Fetching weather data for city 21 busselton
# Fetching weather data for city 22 mataura
# Fetching weather data for city 23 stoyba
# Cannot find city
# Fetching weather data for city 24 kinkala
# Fetching weather data for city 25 anadyr
# Fetching weather data for city 26 bensonville
# Fetching weather data for city 27 new norfolk
# Fetching weather data for city 28 midland
# Fetching weather data for city 29 hay river
# Fetching weather data for city 30 inuvik
# Fetching weather data for city 31 tiksi
# Fetching weather data for city 32 mrakovo
# Fetching weather data for city 33 port alfred
# Fetching weather data for city 34 rawson
# Fetching weather data for city 35 arraial do cabo
# Fetching weather data for city 36 kharan
# Fetching weather data for city 37 palana
# Fetching weather data for city 38 ponta do sol
# Fetching weather data for city 39 launceston
# Fetching weather data for city 40 punta arenas
# Fetching weather data for city 41 sitka
# Fetching weather data for city 42 grand centre
# Cannot find city
# Fetching weather data for city 43 boyuibe
# Fetching weather data for city 44 kapaa
# Fetching weather data for city 45 perez
# Fetching weather data for city 46 atuona
# Fetching weather data for city 47 chokurdakh
# Fetching weather data for city 48 benalla
# Fetching weather data for city 49 mayumba
# Fetching weather data for city 50 srednekolymsk
# Fetching weather data for city 51 ulcinj
# Fetching weather data for city 52 kodiak
# Fetching weather data for city 53 hamilton
# Fetching weather data for city 54 hami
# Fetching weather data for city 55 rosiile
# Fetching weather data for city 56 sao sebastiao
# Fetching weather data for city 57 nikolskoye
# Fetching weather data for city 58 osakarovka
# Fetching weather data for city 59 butaritari
# Fetching weather data for city 60 hilo
# Fetching weather data for city 61 saskylakh
# Fetching weather data for city 62 ushuaia
# Fetching weather data for city 63 dikson
# Fetching weather data for city 64 orillia
# Fetching weather data for city 65 colares
# Fetching weather data for city 66 komsomolskiy
# Fetching weather data for city 67 bredasdorp
# Fetching weather data for city 68 lompoc
# Fetching weather data for city 69 rancho palos verdes
# Fetching weather data for city 70 cabo san lucas
# Fetching weather data for city 71 beringovskiy
# Fetching weather data for city 72 bluff
# Fetching weather data for city 73 hasaki
# Fetching weather data for city 74 flinders
# Fetching weather data for city 75 arti
# Fetching weather data for city 76 waipawa
# Fetching weather data for city 77 avarua
# Fetching weather data for city 78 tasiilaq
# Fetching weather data for city 79 yulara
# Fetching weather data for city 80 saint george
# Fetching weather data for city 81 mys shmidta
# Cannot find city
# Fetching weather data for city 82 mareeba
# Fetching weather data for city 83 esperance
# Fetching weather data for city 84 port moresby
# Fetching weather data for city 85 hambantota
# Fetching weather data for city 86 cidreira
# Fetching weather data for city 87 upernavik
# Fetching weather data for city 88 quarteira
# Fetching weather data for city 89 illoqqortoormiut
# Cannot find city
# Fetching weather data for city 90 cape town
# Fetching weather data for city 91 lorengau
# Fetching weather data for city 92 bourail
# Fetching weather data for city 93 sao joao da barra
# Fetching weather data for city 94 grindavik
# Fetching weather data for city 95 muros
# Fetching weather data for city 96 codrington
# Fetching weather data for city 97 omsukchan
# Fetching weather data for city 98 xunchang
# Fetching weather data for city 99 laem sing
# Fetching weather data for city 100 bowen
# Fetching weather data for city 101 amderma
# Cannot find city
# Fetching weather data for city 102 skalistyy
# Cannot find city
# Fetching weather data for city 103 boende
# Fetching weather data for city 104 simbahan
# Fetching weather data for city 105 talca
# Fetching weather data for city 106 camana
# Fetching weather data for city 107 kenai
# Fetching weather data for city 108 east london
# Fetching weather data for city 109 ambon
# Fetching weather data for city 110 puerto ayora
# Fetching weather data for city 111 isangel
# Fetching weather data for city 112 camopi
# Fetching weather data for city 113 chute-aux-outardes
# Fetching weather data for city 114 geraldton
# Fetching weather data for city 115 pisco
# Fetching weather data for city 116 thompson
# Fetching weather data for city 117 bengkulu
# Fetching weather data for city 118 cumra
# Fetching weather data for city 119 sao filipe
# Fetching weather data for city 120 burnie
# Fetching weather data for city 121 ust-kamchatsk
# Cannot find city
# Fetching weather data for city 122 quatre cocos
# Fetching weather data for city 123 adamas
# Fetching weather data for city 124 mar del plata
# Fetching weather data for city 125 khonuu
# Cannot find city
# Fetching weather data for city 126 louis trichardt
# Fetching weather data for city 127 kaitangata
# Fetching weather data for city 128 longyearbyen
# Fetching weather data for city 129 saint-augustin
# Fetching weather data for city 130 klaksvik
# Fetching weather data for city 131 kudahuvadhoo
# Fetching weather data for city 132 mahebourg
# Fetching weather data for city 133 carnarvon
# Fetching weather data for city 134 taolanaro
# Cannot find city
# Fetching weather data for city 135 bethel
# Fetching weather data for city 136 te anau
# Fetching weather data for city 137 victoria
# Fetching weather data for city 138 yellowknife
# Fetching weather data for city 139 belushya guba
# Cannot find city
# Fetching weather data for city 140 qaanaaq
# Fetching weather data for city 141 hobart
# Fetching weather data for city 142 georgetown
# Fetching weather data for city 143 dunedin
# Fetching weather data for city 144 barbar
# Cannot find city
# Fetching weather data for city 145 deputatskiy
# Fetching weather data for city 146 san jeronimo
# Fetching weather data for city 147 tres arroyos
# Fetching weather data for city 148 tuatapere
# Fetching weather data for city 149 narok
# Fetching weather data for city 150 sisimiut
# Fetching weather data for city 151 narsaq
# Fetching weather data for city 152 barra do pirai
# Fetching weather data for city 153 san rafael
# Fetching weather data for city 154 viedma
# Fetching weather data for city 155 pevek
# Fetching weather data for city 156 terrace
# Fetching weather data for city 157 bandarbeyla
# Fetching weather data for city 158 port macquarie
# Fetching weather data for city 159 saleaula
# Cannot find city
# Fetching weather data for city 160 clyde river
# Fetching weather data for city 161 inhambane
# Fetching weather data for city 162 hualmay
# Fetching weather data for city 163 conde
# Fetching weather data for city 164 shimoda
# Fetching weather data for city 165 gazli
# Fetching weather data for city 166 flagstaff
# Fetching weather data for city 167 kruisfontein
# Fetching weather data for city 168 daud khel
# Fetching weather data for city 169 vaini
# Fetching weather data for city 170 palora
# Fetching weather data for city 171 tura
# Fetching weather data for city 172 port shepstone
# Fetching weather data for city 173 leirvik
# Fetching weather data for city 174 champawat
# Fetching weather data for city 175 bilma
# Fetching weather data for city 176 saint-philippe
# Fetching weather data for city 177 gasa
# Fetching weather data for city 178 toliary
# Cannot find city
# Fetching weather data for city 179 show low
# Fetching weather data for city 180 macaubas
# Fetching weather data for city 181 valer
# Fetching weather data for city 182 dogondoutchi
# Fetching weather data for city 183 kloulklubed
# Fetching weather data for city 184 jamestown
# Fetching weather data for city 185 chapais
# Fetching weather data for city 186 vardo
# Fetching weather data for city 187 tsihombe
# Cannot find city
# Fetching weather data for city 188 guerrero negro
# Fetching weather data for city 189 barrow
# Fetching weather data for city 190 lagoa
# Fetching weather data for city 191 ust-nera
# Fetching weather data for city 192 vilyuysk
# Fetching weather data for city 193 port blair
# Fetching weather data for city 194 oranjemund
# Fetching weather data for city 195 teya
# Fetching weather data for city 196 mount vernon
# Fetching weather data for city 197 cherskiy
# Fetching weather data for city 198 oktyabrskiy
# Fetching weather data for city 199 maceio
# Fetching weather data for city 200 husavik
# Fetching weather data for city 201 souillac
# Fetching weather data for city 202 svebolle
# Fetching weather data for city 203 fare
# Fetching weather data for city 204 jose de freitas
# Fetching weather data for city 205 karasjok
# Fetching weather data for city 206 monte escobedo
# Fetching weather data for city 207 sabang
# Fetching weather data for city 208 ribeira grande
# Fetching weather data for city 209 mangrol
# Fetching weather data for city 210 sterling
# Fetching weather data for city 211 novochernorechenskiy
# Fetching weather data for city 212 halalo
# Cannot find city
# Fetching weather data for city 213 norman wells
# Fetching weather data for city 214 singkang
# Fetching weather data for city 215 xacmaz
# Fetching weather data for city 216 tautira
# Fetching weather data for city 217 timon
# Fetching weather data for city 218 novobiryusinskiy
# Fetching weather data for city 219 dvinskoy
# Fetching weather data for city 220 ngunguru
# Fetching weather data for city 221 leh
# Fetching weather data for city 222 kavieng
# Fetching weather data for city 223 vanimo
# Fetching weather data for city 224 roebourne
# Fetching weather data for city 225 cockburn town
# Fetching weather data for city 226 plettenberg bay
# Fetching weather data for city 227 shizukuishi
# Fetching weather data for city 228 severo-kurilsk
# Fetching weather data for city 229 wasilla
# Fetching weather data for city 230 olavarria
# Fetching weather data for city 231 ola
# Fetching weather data for city 232 vaitupu
# Cannot find city
# Fetching weather data for city 233 constitucion
# Fetching weather data for city 234 kenmare
# Fetching weather data for city 235 whitehorse
# Fetching weather data for city 236 babanusah
# Cannot find city
# Fetching weather data for city 237 marcona
# Cannot find city
# Fetching weather data for city 238 avera
# Fetching weather data for city 239 winnemucca
# Fetching weather data for city 240 torbay
# Fetching weather data for city 241 dolbeau
# Cannot find city
# Fetching weather data for city 242 paucartambo
# Cannot find city
# Fetching weather data for city 243 yarada
# Fetching weather data for city 244 peterhead
# Fetching weather data for city 245 yar-sale
# Fetching weather data for city 246 nizhneyansk
# Cannot find city
# Fetching weather data for city 247 nioro
# Fetching weather data for city 248 tuktoyaktuk
# Fetching weather data for city 249 touros
# Fetching weather data for city 250 taoudenni
# Fetching weather data for city 251 berlevag
# Fetching weather data for city 252 cam ranh
# Fetching weather data for city 253 alyangula
# Fetching weather data for city 254 santiago del estero
# Fetching weather data for city 255 porto novo
# Fetching weather data for city 256 port lincoln
# Fetching weather data for city 257 talnakh
# Fetching weather data for city 258 praia da vitoria
# Fetching weather data for city 259 obluche
# Cannot find city
# Fetching weather data for city 260 dingzhou
# Fetching weather data for city 261 aksha
# Fetching weather data for city 262 freeport
# Fetching weather data for city 263 smithers
# Fetching weather data for city 264 ixtapa
# Fetching weather data for city 265 castro
# Fetching weather data for city 266 itarema
# Fetching weather data for city 267 mount isa
# Fetching weather data for city 268 luderitz
# Fetching weather data for city 269 quelimane
# Fetching weather data for city 270 tazovskiy
# Fetching weather data for city 271 qingan
# Cannot find city
# Fetching weather data for city 272 qinggang
# Fetching weather data for city 273 trunovskoye
# Fetching weather data for city 274 san patricio
# Fetching weather data for city 275 kirkwall
# Fetching weather data for city 276 tual
# Fetching weather data for city 277 sarakhs
# Fetching weather data for city 278 san cristobal
# Fetching weather data for city 279 aksu
# Fetching weather data for city 280 were ilu
# Fetching weather data for city 281 starosubkhangulovo
# Fetching weather data for city 282 namibe
# Fetching weather data for city 283 attawapiskat
# Cannot find city
# Fetching weather data for city 284 orocue
# Fetching weather data for city 285 krasnovka
# Fetching weather data for city 286 alice springs
# Fetching weather data for city 287 fort smith
# Fetching weather data for city 288 nouadhibou
# Fetching weather data for city 289 macamic
# Fetching weather data for city 290 margate
# Fetching weather data for city 291 mindelo
# Fetching weather data for city 292 paradwip
# Cannot find city
# Fetching weather data for city 293 caconda
# Fetching weather data for city 294 desaguadero
# Fetching weather data for city 295 santiago de cao
# Fetching weather data for city 296 riyadh
# Fetching weather data for city 297 airai
# Fetching weather data for city 298 barentsburg
# Cannot find city
# Fetching weather data for city 299 grand gaube
# Fetching weather data for city 300 emerald
# Fetching weather data for city 301 nenjiang
# Fetching weather data for city 302 noumea
# Fetching weather data for city 303 byron bay
# Fetching weather data for city 304 rocha
# Fetching weather data for city 305 hudiksvall
# Fetching weather data for city 306 hobyo
# Fetching weather data for city 307 rasshevatskaya
# Fetching weather data for city 308 grand river south east
# Cannot find city
# Fetching weather data for city 309 kushiro
# Fetching weather data for city 310 merauke
# Fetching weather data for city 311 lithgow
# Fetching weather data for city 312 khatanga
# Fetching weather data for city 313 aksarka
# Fetching weather data for city 314 dasoguz
# Fetching weather data for city 315 yuanping
# Fetching weather data for city 316 ndioum
# Fetching weather data for city 317 jawhar
# Fetching weather data for city 318 severomuysk
# Fetching weather data for city 319 xining
# Fetching weather data for city 320 champasak
# Fetching weather data for city 321 sola
# Fetching weather data for city 322 koumac
# Fetching weather data for city 323 de aar
# Fetching weather data for city 324 vila franca do campo
# Fetching weather data for city 325 katangli
# Fetching weather data for city 326 boyolangu
# Fetching weather data for city 327 bairiki
# Fetching weather data for city 328 hofn
# Fetching weather data for city 329 emba
# Fetching weather data for city 330 eslamshahr
# Fetching weather data for city 331 omboue
# Fetching weather data for city 332 pecangakan
# Fetching weather data for city 333 leningradskiy
# Fetching weather data for city 334 kaka
# Fetching weather data for city 335 broken hill
# Fetching weather data for city 336 dabola
# Fetching weather data for city 337 nhulunbuy
# Fetching weather data for city 338 erenhot
# Fetching weather data for city 339 corrente
# Fetching weather data for city 340 masjed-e soleyman
# Cannot find city
# Fetching weather data for city 341 salamiyah
# Fetching weather data for city 342 casma
# Fetching weather data for city 343 maloshuyka
# Cannot find city
# Fetching weather data for city 344 meulaboh
# Fetching weather data for city 345 kuche
# Cannot find city
# Fetching weather data for city 346 bhag
# Fetching weather data for city 347 penzance
# Fetching weather data for city 348 boguchany
# Fetching weather data for city 349 magadi
# Fetching weather data for city 350 buraydah
# Fetching weather data for city 351 dingle
# Fetching weather data for city 352 bridlington
# Fetching weather data for city 353 verin
# Fetching weather data for city 354 provideniya
# Fetching weather data for city 355 naftah
# Cannot find city
# Fetching weather data for city 356 sarkand
# Fetching weather data for city 357 qaqortoq
# Fetching weather data for city 358 ondorhaan
# Cannot find city
# Fetching weather data for city 359 lhokseumawe
# Fetching weather data for city 360 prince rupert
# Fetching weather data for city 361 caravelas
# Fetching weather data for city 362 tumannyy
# Cannot find city
# Fetching weather data for city 363 gurgan
# Cannot find city
# Fetching weather data for city 364 flin flon
# Fetching weather data for city 365 matara
# Fetching weather data for city 366 louisbourg
# Cannot find city
# Fetching weather data for city 367 jiuquan
# Fetching weather data for city 368 richards bay
# Fetching weather data for city 369 antequera
# Fetching weather data for city 370 kankon
# Fetching weather data for city 371 nichinan
# Fetching weather data for city 372 batagay
# Fetching weather data for city 373 portland
# Fetching weather data for city 374 porto santo
# Fetching weather data for city 375 ardalstangen
# Fetching weather data for city 376 progreso
# Fetching weather data for city 377 lolua
# Cannot find city
# Fetching weather data for city 378 rosaryville
# Fetching weather data for city 379 bilibino
# Fetching weather data for city 380 ratangarh
# Fetching weather data for city 381 port hedland
# Fetching weather data for city 382 severnyy
# Fetching weather data for city 383 togur
# Fetching weather data for city 384 vao
# Fetching weather data for city 385 treinta y tres
# Fetching weather data for city 386 mayskiy
# Fetching weather data for city 387 oranjestad
# Fetching weather data for city 388 jacqueville
# Fetching weather data for city 389 bahia de caraquez
# Fetching weather data for city 390 yeppoon
# Fetching weather data for city 391 kumluca
# Fetching weather data for city 392 sioux lookout
# Fetching weather data for city 393 marawi
# Fetching weather data for city 394 plainview
# Fetching weather data for city 395 nachingwea
# Fetching weather data for city 396 boa vista
# Fetching weather data for city 397 snezhnogorsk
# Fetching weather data for city 398 kirensk
# Fetching weather data for city 399 sergeyevka
# Fetching weather data for city 400 mitu
# Fetching weather data for city 401 polis
# Fetching weather data for city 402 dolinsk
# Fetching weather data for city 403 sao jose da coroa grande
# Fetching weather data for city 404 ratne
# Fetching weather data for city 405 bantou
# Fetching weather data for city 406 baykit
# Fetching weather data for city 407 hurricane
# Fetching weather data for city 408 iquitos
# Fetching weather data for city 409 chuy
# Fetching weather data for city 410 naryan-mar
# Fetching weather data for city 411 sur
# Fetching weather data for city 412 oracon
# Fetching weather data for city 413 mafinga
# Fetching weather data for city 414 darlington
# Fetching weather data for city 415 porto nacional
# Fetching weather data for city 416 port charlotte
# Fetching weather data for city 417 oum hadjer
# Fetching weather data for city 418 svarstad
# Fetching weather data for city 419 westport
# Fetching weather data for city 420 carora
# Fetching weather data for city 421 puerto del rosario
# Fetching weather data for city 422 belmonte
# Fetching weather data for city 423 beloha
# Fetching weather data for city 424 saint anthony
# Fetching weather data for city 425 berdigestyakh
# Fetching weather data for city 426 aykhal
# Fetching weather data for city 427 faanui
# Fetching weather data for city 428 port said
# Fetching weather data for city 429 partyzany
# Fetching weather data for city 430 rock springs
# Fetching weather data for city 431 guajara-mirim
# Cannot find city
# Fetching weather data for city 432 kamaishi
# Fetching weather data for city 433 wagga wagga
# Fetching weather data for city 434 amapa
# Fetching weather data for city 435 ballina
# Fetching weather data for city 436 baherden
# Fetching weather data for city 437 camacha
# Fetching weather data for city 438 dayong
# Fetching weather data for city 439 valparaiso
# Fetching weather data for city 440 panzhihua
# Fetching weather data for city 441 carbondale
# Fetching weather data for city 442 kemijarvi
# Fetching weather data for city 443 saint-francois
# Fetching weather data for city 444 tiznit
# Fetching weather data for city 445 esslingen
# Fetching weather data for city 446 seit
# Cannot find city
# Fetching weather data for city 447 biggar
# Fetching weather data for city 448 abu kamal
# Fetching weather data for city 449 tshikapa
# Fetching weather data for city 450 bakchar
# Fetching weather data for city 451 walvis bay
# Fetching weather data for city 452 gorontalo
# Fetching weather data for city 453 vanavara
# Fetching weather data for city 454 luanda
# Fetching weather data for city 455 amarillo
# Fetching weather data for city 456 pangnirtung
# Fetching weather data for city 457 sambava
# Fetching weather data for city 458 lahij
# Fetching weather data for city 459 port-gentil
# Fetching weather data for city 460 yakeshi
# Fetching weather data for city 461 ostrovnoy
# Fetching weather data for city 462 baneh
# Fetching weather data for city 463 thiruvananthapuram
# Fetching weather data for city 464 middlebury
# Fetching weather data for city 465 grobina
# Fetching weather data for city 466 moctezuma
# Fetching weather data for city 467 sakaiminato
# Fetching weather data for city 468 katha
# Cannot find city
# Fetching weather data for city 469 obanazawa
# Fetching weather data for city 470 severnoye
# Fetching weather data for city 471 dwarka
# Fetching weather data for city 472 aguimes
# Fetching weather data for city 473 pemberton
# Fetching weather data for city 474 kadykchan
# Cannot find city
# Fetching weather data for city 475 sao borja
# Fetching weather data for city 476 zwedru
# Fetching weather data for city 477 biak
# Fetching weather data for city 478 porbandar
# Fetching weather data for city 479 nome
# Fetching weather data for city 480 arkul
# Fetching weather data for city 481 antalaha
# Fetching weather data for city 482 port hardy
# Fetching weather data for city 483 kalevala
# Fetching weather data for city 484 romny
# Fetching weather data for city 485 tempoal
# Cannot find city
# Fetching weather data for city 486 araceli
# Fetching weather data for city 487 canico
# Fetching weather data for city 488 soyo
# Fetching weather data for city 489 yankton
# Fetching weather data for city 490 ilulissat
# Fetching weather data for city 491 mundo nuevo
# Fetching weather data for city 492 port-de-paix
# Cannot find city
# Fetching weather data for city 493 mehamn
# Fetching weather data for city 494 kalamare
# Fetching weather data for city 495 rio gallegos
# Fetching weather data for city 496 saint pete beach
# Fetching weather data for city 497 bubaque
# Fetching weather data for city 498 krasnoyarsk-66
# Cannot find city
# Fetching weather data for city 499 malakal
# Fetching weather data for city 500 golspie
# Fetching weather data for city 501 nelson bay
# Fetching weather data for city 502 athabasca
# Fetching weather data for city 503 sokoni
# Fetching weather data for city 504 bari sadri
# Fetching weather data for city 505 petropavlovsk-kamchatskiy
# Fetching weather data for city 506 siocon
# Fetching weather data for city 507 tutoia
# Fetching weather data for city 508 deniliquin
# Fetching weather data for city 509 gigmoto
# Fetching weather data for city 510 bathsheba
# Fetching weather data for city 511 basoko
# Fetching weather data for city 512 katsuura
# Fetching weather data for city 513 indian head
# Fetching weather data for city 514 north bend
# Fetching weather data for city 515 severo-yeniseyskiy
# Fetching weather data for city 516 lucapa
# Fetching weather data for city 517 utiroa
# Cannot find city
# Fetching weather data for city 518 poum
# Fetching weather data for city 519 qui nhon
# Fetching weather data for city 520 ippy
# Fetching weather data for city 521 jak
# Fetching weather data for city 522 turinskaya sloboda
# Fetching weather data for city 523 chara
# Fetching weather data for city 524 yumen
# Fetching weather data for city 525 upington
# Fetching weather data for city 526 saint-pacome
# Cannot find city
# Fetching weather data for city 527 garoua
# Fetching weather data for city 528 okhotsk
# Fetching weather data for city 529 ulladulla
# Fetching weather data for city 530 mata
# Fetching weather data for city 531 slave lake
# Fetching weather data for city 532 vila velha
# Fetching weather data for city 533 bur gabo
# Cannot find city
# Fetching weather data for city 534 seoul
# Fetching weather data for city 535 olgod
# Fetching weather data for city 536 le pont-de-claix
# Fetching weather data for city 537 sidi qasim
# Cannot find city
# Fetching weather data for city 538 presidencia roque saenz pena
# Fetching weather data for city 539 qandala
# Fetching weather data for city 540 phibun mangsahan
# Fetching weather data for city 541 baruun-urt
# Fetching weather data for city 542 cabra
# Fetching weather data for city 543 shingu
# Fetching weather data for city 544 sydney mines
# Fetching weather data for city 545 kavaratti
# Fetching weather data for city 546 coihaique
# Fetching weather data for city 547 frederikshavn
# Fetching weather data for city 548 mokhsogollokh
# Fetching weather data for city 549 olafsvik
# Fetching weather data for city 550 vestmanna
# Fetching weather data for city 551 sentyabrskiy
# Cannot find city
# Fetching weather data for city 552 guaruja
# Fetching weather data for city 553 menongue
# Fetching weather data for city 554 brae
# Fetching weather data for city 555 naze
# Fetching weather data for city 556 bolshoye sorokino
# Cannot find city
# Fetching weather data for city 557 egvekinot
# Fetching weather data for city 558 fortuna
# Fetching weather data for city 559 gorgan
# Fetching weather data for city 560 agadir
# Fetching weather data for city 561 paris
# Fetching weather data for city 562 thinadhoo
# Fetching weather data for city 563 road town
# Fetching weather data for city 564 christchurch
# Fetching weather data for city 565 cayenne
# Fetching weather data for city 566 miyazu
# Fetching weather data for city 567 ryde
# Fetching weather data for city 568 mitsamiouli
# Fetching weather data for city 569 novopetrovskoye
# Fetching weather data for city 570 jiddah
# Cannot find city
# Fetching weather data for city 571 pokhara
# Fetching weather data for city 572 karauzyak
# Cannot find city
# Fetching weather data for city 573 bonthe
# Fetching weather data for city 574 bitung
# Fetching weather data for city 575 sungaipenuh
# Fetching weather data for city 576 tineo
# Fetching weather data for city 577 bytow
# Fetching weather data for city 578 zyryanka
# Fetching weather data for city 579 tessalit
# Fetching weather data for city 580 north platte
# Fetching weather data for city 581 tampakan
# Fetching weather data for city 582 plaridel
# Fetching weather data for city 583 santarem
# Fetching weather data for city 584 goderich
# Fetching weather data for city 585 lethem
# Fetching weather data for city 586 kalmunai
# Fetching weather data for city 587 coihueco
# Fetching weather data for city 588 ayia galini
# Fetching weather data for city 589 rolim de moura
# Cannot find city
# Fetching weather data for city 590 harda
# Fetching weather data for city 591 aras
# Fetching weather data for city 592 oksfjord
# Fetching weather data for city 593 kandrian
# Fetching weather data for city 594 freetown
# Fetching weather data for city 595 kandy
# Fetching weather data for city 596 sao miguel do araguaia
# Fetching weather data for city 597 morant bay
# Fetching weather data for city 598 viligili
# Cannot find city
# Fetching weather data for city 599 bolshiye uki
# Cannot find city
# Fetching weather data for city 600 trincomalee
# Fetching weather data for city 601 ulaangom
# Fetching weather data for city 602 choa saidan shah
# Fetching weather data for city 603 ancud
# Fetching weather data for city 604 colac
# Fetching weather data for city 605 kawalu

# %%
cities
# Out:
# ['rikitea',
#  'hithadhoo',
#  'henties bay',
#  'asau',
#  'phayao',
#  'beaverlodge',
#  'dindori',
#  'miraflores',
#  'nanortalik',
#  'kahului',
#  'albany',
#  'itoman',
#  'bambous virieux',
#  'samusu',
#  'hermanus',
#  'tawkar',
#  'salalah',
#  'lebu',
#  'saldanha',
#  'port elizabeth',
#  'busselton',
#  'mataura',
#  'stoyba',
#  'kinkala',
#  'anadyr',
#  'bensonville',
#  'new norfolk',
#  'midland',
#  'hay river',
#  'inuvik',
#  'tiksi',
#  'mrakovo',
#  'port alfred',
#  'rawson',
#  'arraial do cabo',
#  'kharan',
#  'palana',
#  'ponta do sol',
#  'launceston',
#  'punta arenas',
#  'sitka',
#  'grand centre',
#  'boyuibe',
#  'kapaa',
#  'perez',
#  'atuona',
#  'chokurdakh',
#  'benalla',
#  'mayumba',
#  'srednekolymsk',
#  'ulcinj',
#  'kodiak',
#  'hamilton',
#  'hami',
#  'rosiile',
#  'sao sebastiao',
#  'nikolskoye',
#  'osakarovka',
#  'butaritari',
#  'hilo',
#  'saskylakh',
#  'ushuaia',
#  'dikson',
#  'orillia',
#  'colares',
#  'komsomolskiy',
#  'bredasdorp',
#  'lompoc',
#  'rancho palos verdes',
#  'cabo san lucas',
#  'beringovskiy',
#  'bluff',
#  'hasaki',
#  'flinders',
#  'arti',
#  'waipawa',
#  'avarua',
#  'tasiilaq',
#  'yulara',
#  'saint george',
#  'mys shmidta',
#  'mareeba',
#  'esperance',
#  'port moresby',
#  'hambantota',
#  'cidreira',
#  'upernavik',
#  'quarteira',
#  'illoqqortoormiut',
#  'cape town',
#  'lorengau',
#  'bourail',
#  'sao joao da barra',
#  'grindavik',
#  'muros',
#  'codrington',
#  'omsukchan',
#  'xunchang',
#  'laem sing',
#  'bowen',
#  'amderma',
#  'skalistyy',
#  'boende',
#  'simbahan',
#  'talca',
#  'camana',
#  'kenai',
#  'east london',
#  'ambon',
#  'puerto ayora',
#  'isangel',
#  'camopi',
#  'chute-aux-outardes',
#  'geraldton',
#  'pisco',
#  'thompson',
#  'bengkulu',
#  'cumra',
#  'sao filipe',
#  'burnie',
#  'ust-kamchatsk',
#  'quatre cocos',
#  'adamas',
#  'mar del plata',
#  'khonuu',
#  'louis trichardt',
#  'kaitangata',
#  'longyearbyen',
#  'saint-augustin',
#  'klaksvik',
#  'kudahuvadhoo',
#  'mahebourg',
#  'carnarvon',
#  'taolanaro',
#  'bethel',
#  'te anau',
#  'victoria',
#  'yellowknife',
#  'belushya guba',
#  'qaanaaq',
#  'hobart',
#  'georgetown',
#  'dunedin',
#  'barbar',
#  'deputatskiy',
#  'san jeronimo',
#  'tres arroyos',
#  'tuatapere',
#  'narok',
#  'sisimiut',
#  'narsaq',
#  'barra do pirai',
#  'san rafael',
#  'viedma',
#  'pevek',
#  'terrace',
#  'bandarbeyla',
#  'port macquarie',
#  'saleaula',
#  'clyde river',
#  'inhambane',
#  'hualmay',
#  'conde',
#  'shimoda',
#  'gazli',
#  'flagstaff',
#  'kruisfontein',
#  'daud khel',
#  'vaini',
#  'palora',
#  'tura',
#  'port shepstone',
#  'leirvik',
#  'champawat',
#  'bilma',
#  'saint-philippe',
#  'gasa',
#  'toliary',
#  'show low',
#  'macaubas',
#  'valer',
#  'dogondoutchi',
#  'kloulklubed',
#  'jamestown',
#  'chapais',
#  'vardo',
#  'tsihombe',
#  'guerrero negro',
#  'barrow',
#  'lagoa',
#  'ust-nera',
#  'vilyuysk',
#  'port blair',
#  'oranjemund',
#  'teya',
#  'mount vernon',
#  'cherskiy',
#  'oktyabrskiy',
#  'maceio',
#  'husavik',
#  'souillac',
#  'svebolle',
#  'fare',
#  'jose de freitas',
#  'karasjok',
#  'monte escobedo',
#  'sabang',
#  'ribeira grande',
#  'mangrol',
#  'sterling',
#  'novochernorechenskiy',
#  'halalo',
#  'norman wells',
#  'singkang',
#  'xacmaz',
#  'tautira',
#  'timon',
#  'novobiryusinskiy',
#  'dvinskoy',
#  'ngunguru',
#  'leh',
#  'kavieng',
#  'vanimo',
#  'roebourne',
#  'cockburn town',
#  'plettenberg bay',
#  'shizukuishi',
#  'severo-kurilsk',
#  'wasilla',
#  'olavarria',
#  'ola',
#  'vaitupu',
#  'constitucion',
#  'kenmare',
#  'whitehorse',
#  'babanusah',
#  'marcona',
#  'avera',
#  'winnemucca',
#  'torbay',
#  'dolbeau',
#  'paucartambo',
#  'yarada',
#  'peterhead',
#  'yar-sale',
#  'nizhneyansk',
#  'nioro',
#  'tuktoyaktuk',
#  'touros',
#  'taoudenni',
#  'berlevag',
#  'cam ranh',
#  'alyangula',
#  'santiago del estero',
#  'porto novo',
#  'port lincoln',
#  'talnakh',
#  'praia da vitoria',
#  'obluche',
#  'dingzhou',
#  'aksha',
#  'freeport',
#  'smithers',
#  'ixtapa',
#  'castro',
#  'itarema',
#  'mount isa',
#  'luderitz',
#  'quelimane',
#  'tazovskiy',
#  'qingan',
#  'qinggang',
#  'trunovskoye',
#  'san patricio',
#  'kirkwall',
#  'tual',
#  'sarakhs',
#  'san cristobal',
#  'aksu',
#  'were ilu',
#  'starosubkhangulovo',
#  'namibe',
#  'attawapiskat',
#  'orocue',
#  'krasnovka',
#  'alice springs',
#  'fort smith',
#  'nouadhibou',
#  'macamic',
#  'margate',
#  'mindelo',
#  'paradwip',
#  'caconda',
#  'desaguadero',
#  'santiago de cao',
#  'riyadh',
#  'airai',
#  'barentsburg',
#  'grand gaube',
#  'emerald',
#  'nenjiang',
#  'noumea',
#  'byron bay',
#  'rocha',
#  'hudiksvall',
#  'hobyo',
#  'rasshevatskaya',
#  'grand river south east',
#  'kushiro',
#  'merauke',
#  'lithgow',
#  'khatanga',
#  'aksarka',
#  'dasoguz',
#  'yuanping',
#  'ndioum',
#  'jawhar',
#  'severomuysk',
#  'xining',
#  'champasak',
#  'sola',
#  'koumac',
#  'de aar',
#  'vila franca do campo',
#  'katangli',
#  'boyolangu',
#  'bairiki',
#  'hofn',
#  'emba',
#  'eslamshahr',
#  'omboue',
#  'pecangakan',
#  'leningradskiy',
#  'kaka',
#  'broken hill',
#  'dabola',
#  'nhulunbuy',
#  'erenhot',
#  'corrente',
#  'masjed-e soleyman',
#  'salamiyah',
#  'casma',
#  'maloshuyka',
#  'meulaboh',
#  'kuche',
#  'bhag',
#  'penzance',
#  'boguchany',
#  'magadi',
#  'buraydah',
#  'dingle',
#  'bridlington',
#  'verin',
#  'provideniya',
#  'naftah',
#  'sarkand',
#  'qaqortoq',
#  'ondorhaan',
#  'lhokseumawe',
#  'prince rupert',
#  'caravelas',
#  'tumannyy',
#  'gurgan',
#  'flin flon',
#  'matara',
#  'louisbourg',
#  'jiuquan',
#  'richards bay',
#  'antequera',
#  'kankon',
#  'nichinan',
#  'batagay',
#  'portland',
#  'porto santo',
#  'ardalstangen',
#  'progreso',
#  'lolua',
#  'rosaryville',
#  'bilibino',
#  'ratangarh',
#  'port hedland',
#  'severnyy',
#  'togur',
#  'vao',
#  'treinta y tres',
#  'mayskiy',
#  'oranjestad',
#  'jacqueville',
#  'bahia de caraquez',
#  'yeppoon',
#  'kumluca',
#  'sioux lookout',
#  'marawi',
#  'plainview',
#  'nachingwea',
#  'boa vista',
#  'snezhnogorsk',
#  'kirensk',
#  'sergeyevka',
#  'mitu',
#  'polis',
#  'dolinsk',
#  'sao jose da coroa grande',
#  'ratne',
#  'bantou',
#  'baykit',
#  'hurricane',
#  'iquitos',
#  'chuy',
#  'naryan-mar',
#  'sur',
#  'oracon',
#  'mafinga',
#  'darlington',
#  'porto nacional',
#  'port charlotte',
#  'oum hadjer',
#  'svarstad',
#  'westport',
#  'carora',
#  'puerto del rosario',
#  'belmonte',
#  'beloha',
#  'saint anthony',
#  'berdigestyakh',
#  'aykhal',
#  'faanui',
#  'port said',
#  'partyzany',
#  'rock springs',
#  'guajara-mirim',
#  'kamaishi',
#  'wagga wagga',
#  'amapa',
#  'ballina',
#  'baherden',
#  'camacha',
#  'dayong',
#  'valparaiso',
#  'panzhihua',
#  'carbondale',
#  'kemijarvi',
#  'saint-francois',
#  'tiznit',
#  'esslingen',
#  'seit',
#  'biggar',
#  'abu kamal',
#  'tshikapa',
#  'bakchar',
#  'walvis bay',
#  'gorontalo',
#  'vanavara',
#  'luanda',
#  'amarillo',
#  'pangnirtung',
#  'sambava',
#  'lahij',
#  'port-gentil',
#  'yakeshi',
#  'ostrovnoy',
#  'baneh',
#  'thiruvananthapuram',
#  'middlebury',
#  'grobina',
#  'moctezuma',
#  'sakaiminato',
#  'katha',
#  'obanazawa',
#  'severnoye',
#  'dwarka',
#  'aguimes',
#  'pemberton',
#  'kadykchan',
#  'sao borja',
#  'zwedru',
#  'biak',
#  'porbandar',
#  'nome',
#  'arkul',
#  'antalaha',
#  'port hardy',
#  'kalevala',
#  'romny',
#  'tempoal',
#  'araceli',
#  'canico',
#  'soyo',
#  'yankton',
#  'ilulissat',
#  'mundo nuevo',
#  'port-de-paix',
#  'mehamn',
#  'kalamare',
#  'rio gallegos',
#  'saint pete beach',
#  'bubaque',
#  'krasnoyarsk-66',
#  'malakal',
#  'golspie',
#  'nelson bay',
#  'athabasca',
#  'sokoni',
#  'bari sadri',
#  'petropavlovsk-kamchatskiy',
#  'siocon',
#  'tutoia',
#  'deniliquin',
#  'gigmoto',
#  'bathsheba',
#  'basoko',
#  'katsuura',
#  'indian head',
#  'north bend',
#  'severo-yeniseyskiy',
#  'lucapa',
#  'utiroa',
#  'poum',
#  'qui nhon',
#  'ippy',
#  'jak',
#  'turinskaya sloboda',
#  'chara',
#  'yumen',
#  'upington',
#  'saint-pacome',
#  'garoua',
#  'okhotsk',
#  'ulladulla',
#  'mata',
#  'slave lake',
#  'vila velha',
#  'bur gabo',
#  'seoul',
#  'olgod',
#  'le pont-de-claix',
#  'sidi qasim',
#  'presidencia roque saenz pena',
#  'qandala',
#  'phibun mangsahan',
#  'baruun-urt',
#  'cabra',
#  'shingu',
#  'sydney mines',
#  'kavaratti',
#  'coihaique',
#  'frederikshavn',
#  'mokhsogollokh',
#  'olafsvik',
#  'vestmanna',
#  'sentyabrskiy',
#  'guaruja',
#  'menongue',
#  'brae',
#  'naze',
#  'bolshoye sorokino',
#  'egvekinot',
#  'fortuna',
#  'gorgan',
#  'agadir',
#  'paris',
#  'thinadhoo',
#  'road town',
#  'christchurch',
#  'cayenne',
#  'miyazu',
#  'ryde',
#  'mitsamiouli',
#  'novopetrovskoye',
#  'jiddah',
#  'pokhara',
#  'karauzyak',
#  'bonthe',
#  'bitung',
#  'sungaipenuh',
#  'tineo',
#  'bytow',
#  'zyryanka',
#  'tessalit',
#  'north platte',
#  'tampakan',
#  'plaridel',
#  'santarem',
#  'goderich',
#  'lethem',
#  'kalmunai',
#  'coihueco',
#  'ayia galini',
#  'rolim de moura',
#  'harda',
#  'aras',
#  'oksfjord',
#  'kandrian',
#  'freetown',
#  'kandy',
#  'sao miguel do araguaia',
#  'morant bay',
#  'viligili',
#  'bolshiye uki',
#  'trincomalee',
#  'ulaangom',
#  'choa saidan shah',
#  'ancud',
#  'colac',
#  'kawalu']

# %%
city_data = {"city"}
# Out:
#   File "<ipython-input-9-39343bc3da1f>", line 1
#     df = pd.read_json(r response_json)
#                                     ^
# SyntaxError: invalid syntax

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | darhan
# Processing Record 3 of Set 1 | tarakan
# Processing Record 4 of Set 1 | komsomolskiy
# Processing Record 5 of Set 1 | souillac
# Processing Record 6 of Set 1 | jiuquan
# Processing Record 7 of Set 1 | sesheke
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | clarence town
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | magadan
# Processing Record 12 of Set 1 | salym
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | arys
# Processing Record 16 of Set 1 | prince rupert
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | rio gallegos
# Processing Record 22 of Set 1 | kropotkin
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | dahra
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | stephenville
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | north bend
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | faya
# Processing Record 31 of Set 1 | vryburg
# Processing Record 32 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | zhigansk
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | margate
# Processing Record 38 of Set 1 | oksfjord
# Processing Record 39 of Set 1 | chumikan
# Processing Record 40 of Set 1 | kudat
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | laguna
# Processing Record 43 of Set 1 | abu zabad
# Processing Record 44 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 45 of Set 1 | saint-joseph
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | kirkwall
# Processing Record 50 of Set 1 | luderitz
# Processing Record 0 of Set 2 | bethel
# Processing Record 1 of Set 2 | vao
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | melo
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | college
# Processing Record 6 of Set 2 | prinos
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | cabo rojo
# Processing Record 9 of Set 2 | nuevo ideal
# Processing Record 10 of Set 2 | yumen
# Processing Record 11 of Set 2 | khonsa
# Processing Record 12 of Set 2 | biloela
# Processing Record 13 of Set 2 | sungaipenuh
# Processing Record 14 of Set 2 | namatanai
# Processing Record 15 of Set 2 | kungurtug
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | san rafael
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | hovd
# Processing Record 21 of Set 2 | isangel
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | humenne
# Processing Record 24 of Set 2 | natal
# Processing Record 25 of Set 2 | moron
# Processing Record 26 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | poya
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | pangai
# Processing Record 31 of Set 2 | havre-saint-pierre
# Processing Record 32 of Set 2 | takoradi
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | kirksville
# Processing Record 35 of Set 2 | pangody
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | borujan
# City not found. Skipping...
# Processing Record 39 of Set 2 | cambridge
# Processing Record 40 of Set 2 | damaturu
# Processing Record 41 of Set 2 | bardiyah
# City not found. Skipping...
# Processing Record 42 of Set 2 | carbonear
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | charlestown
# Processing Record 46 of Set 2 | mixtepec
# City not found. Skipping...
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | boissevain
# Processing Record 49 of Set 2 | bluff
# Processing Record 0 of Set 3 | kudahuvadhoo
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | tairua
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | silver city
# Processing Record 6 of Set 3 | veracruz
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | rincon
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | toktogul
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | yilan
# Processing Record 14 of Set 3 | mumford
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | diffa
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | yambio
# City not found. Skipping...
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | ribeira grande
# Processing Record 21 of Set 3 | dana point
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | barabinsk
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | malinovoye ozero
# Processing Record 28 of Set 3 | ambatofinandrahana
# Processing Record 29 of Set 3 | puerto del rosario
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | zhezkazgan
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | batagay-alyta
# Processing Record 35 of Set 3 | baltiysk
# Processing Record 36 of Set 3 | parfino
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | mackenzie
# Processing Record 40 of Set 3 | lebanon
# Processing Record 41 of Set 3 | nishihara
# Processing Record 42 of Set 3 | antalaha
# Processing Record 43 of Set 3 | narsaq
# Processing Record 44 of Set 3 | hami
# Processing Record 45 of Set 3 | shaoyang
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 3 | leningradskiy
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 0 of Set 4 | mehamn
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | bara
# Processing Record 3 of Set 4 | krasnoselkup
# City not found. Skipping...
# Processing Record 4 of Set 4 | risch
# Processing Record 5 of Set 4 | along
# Processing Record 6 of Set 4 | vestmanna
# Processing Record 7 of Set 4 | mwinilunga
# Processing Record 8 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 4 | pozo colorado
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | werder
# Processing Record 12 of Set 4 | lovington
# Processing Record 13 of Set 4 | qasigiannguit
# Processing Record 14 of Set 4 | mackay
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | sisimiut
# Processing Record 18 of Set 4 | banda aceh
# Processing Record 19 of Set 4 | fortuna
# Processing Record 20 of Set 4 | ouadda
# Processing Record 21 of Set 4 | sucua
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | araouane
# Processing Record 25 of Set 4 | barra patuca
# Processing Record 26 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 4 | wattegama
# Processing Record 29 of Set 4 | tuktoyaktuk
# Processing Record 30 of Set 4 | tabou
# Processing Record 31 of Set 4 | arraial do cabo
# Processing Record 32 of Set 4 | stabat
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | sumbawanga
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | bambous virieux
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | hibbing
# Processing Record 41 of Set 4 | bandar-e lengeh
# Processing Record 42 of Set 4 | viedma
# Processing Record 43 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | port keats
# Processing Record 46 of Set 4 | jinchang
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | fairbanks
# Processing Record 49 of Set 4 | olupona
# Processing Record 0 of Set 5 | genhe
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | williamsburg
# Processing Record 3 of Set 5 | anloga
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | saint-philippe
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 5 | dalvik
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | inta
# Processing Record 12 of Set 5 | naze
# Processing Record 13 of Set 5 | juneau
# Processing Record 14 of Set 5 | kurumkan
# Processing Record 15 of Set 5 | ranong
# Processing Record 16 of Set 5 | cockburn town
# Processing Record 17 of Set 5 | sakakah
# City not found. Skipping...
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | hoquiam
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | placido de castro
# Processing Record 24 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 25 of Set 5 | suksun
# Processing Record 26 of Set 5 | bengkulu
# City not found. Skipping...
# Processing Record 27 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | ust-barguzin
# Processing Record 31 of Set 5 | itacare
# Processing Record 32 of Set 5 | nacogdoches
# Processing Record 33 of Set 5 | cape canaveral
# Processing Record 34 of Set 5 | puri
# Processing Record 35 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 5 | jubayl
# City not found. Skipping...
# Processing Record 37 of Set 5 | tarnow
# Processing Record 38 of Set 5 | vicuna
# City not found. Skipping...
# Processing Record 39 of Set 5 | jumla
# Processing Record 40 of Set 5 | ust-kuyga
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | rocha
# Processing Record 43 of Set 5 | tasiilaq
# Processing Record 44 of Set 5 | ribeira brava
# Processing Record 45 of Set 5 | norrtalje
# Processing Record 46 of Set 5 | warrington
# Processing Record 47 of Set 5 | noumea
# Processing Record 48 of Set 5 | akyab
# City not found. Skipping...
# Processing Record 49 of Set 5 | meadow lake
# Processing Record 0 of Set 6 | chimoio
# Processing Record 1 of Set 6 | oussouye
# Processing Record 2 of Set 6 | gazojak
# Processing Record 3 of Set 6 | balikpapan
# Processing Record 4 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 5 of Set 6 | torbay
# Processing Record 6 of Set 6 | elko
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | saquena
# Processing Record 9 of Set 6 | makokou
# Processing Record 10 of Set 6 | hambantota
# Processing Record 11 of Set 6 | beidao
# Processing Record 12 of Set 6 | praia da vitoria
# Processing Record 13 of Set 6 | port blair
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | awbari
# Processing Record 16 of Set 6 | reconquista
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | teya
# Processing Record 19 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 6 | edinet
# Processing Record 21 of Set 6 | taoudenni
# Processing Record 22 of Set 6 | goundam
# Processing Record 23 of Set 6 | socorro
# Processing Record 24 of Set 6 | merrill
# Processing Record 25 of Set 6 | vagay
# Processing Record 26 of Set 6 | comodoro rivadavia
# Processing Record 27 of Set 6 | pudozh
# Processing Record 28 of Set 6 | sambava
# Processing Record 29 of Set 6 | batesville
# Processing Record 30 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 6 | itaituba
# Processing Record 32 of Set 6 | la asuncion
# Processing Record 33 of Set 6 | east london
# Processing Record 34 of Set 6 | chipinge
# Processing Record 35 of Set 6 | cedartown
# Processing Record 36 of Set 6 | miranda
# Processing Record 37 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | abong mbang
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | canon city
# Processing Record 42 of Set 6 | santa quiteria do maranhao
# Processing Record 43 of Set 6 | ryotsu
# Processing Record 44 of Set 6 | pacific grove
# Processing Record 45 of Set 6 | kishi
# Processing Record 46 of Set 6 | obihiro
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | saint augustine
# Processing Record 49 of Set 6 | bushehr
# Processing Record 0 of Set 7 | nizhniy kuranakh
# Processing Record 1 of Set 7 | bonthe
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | nizwa
# Processing Record 4 of Set 7 | kamenka
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | saint anthony
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | riyadh
# Processing Record 9 of Set 7 | malim
# Processing Record 10 of Set 7 | makakilo city
# Processing Record 11 of Set 7 | henties bay
# Processing Record 12 of Set 7 | caravelas
# Processing Record 13 of Set 7 | gazli
# Processing Record 14 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | san juan
# Processing Record 16 of Set 7 | moose factory
# Processing Record 17 of Set 7 | kashi
# City not found. Skipping...
# Processing Record 18 of Set 7 | fuerte olimpo
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | raca
# Processing Record 21 of Set 7 | san quintin
# Processing Record 22 of Set 7 | sedro-woolley
# Processing Record 23 of Set 7 | berdigestyakh
# Processing Record 24 of Set 7 | high level
# Processing Record 25 of Set 7 | khorramshahr
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | emba
# Processing Record 28 of Set 7 | farcasu
# Processing Record 29 of Set 7 | kruisfontein
# Processing Record 30 of Set 7 | garango
# Processing Record 31 of Set 7 | boa vista
# Processing Record 32 of Set 7 | novopskov
# Processing Record 33 of Set 7 | shimoda
# Processing Record 34 of Set 7 | portland
# Processing Record 35 of Set 7 | waingapu
# Processing Record 36 of Set 7 | zuwarah
# Processing Record 37 of Set 7 | muroto
# Processing Record 38 of Set 7 | sao filipe
# Processing Record 39 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 7 | lunenburg
# Processing Record 41 of Set 7 | novyy urengoy
# Processing Record 42 of Set 7 | ferry pass
# Processing Record 43 of Set 7 | crotone
# Processing Record 44 of Set 7 | arlit
# Processing Record 45 of Set 7 | auki
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | ilhabela
# Processing Record 48 of Set 7 | kirakira
# Processing Record 49 of Set 7 | cidreira
# Processing Record 0 of Set 8 | chambas
# Processing Record 1 of Set 8 | gat
# Processing Record 2 of Set 8 | petatlan
# Processing Record 3 of Set 8 | nha trang
# Processing Record 4 of Set 8 | hermosillo
# Processing Record 5 of Set 8 | airai
# Processing Record 6 of Set 8 | kahului
# Processing Record 7 of Set 8 | yeppoon
# Processing Record 8 of Set 8 | manavgat
# Processing Record 9 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 10 of Set 8 | xambioa
# City not found. Skipping...
# Processing Record 11 of Set 8 | katima mulilo
# Processing Record 12 of Set 8 | carutapera
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | haines junction
# Processing Record 15 of Set 8 | half moon bay
# Processing Record 16 of Set 8 | vanavara
# Processing Record 17 of Set 8 | santander
# Processing Record 18 of Set 8 | amuntai
# Processing Record 19 of Set 8 | esmeraldas
# Processing Record 20 of Set 8 | okhotsk
# Processing Record 21 of Set 8 | datong
# Processing Record 22 of Set 8 | sidi ali
# Processing Record 23 of Set 8 | muravlenko
# Processing Record 24 of Set 8 | amahai
# Processing Record 25 of Set 8 | santa isabel do rio negro
# Processing Record 26 of Set 8 | wageningen
# Processing Record 27 of Set 8 | svetlogorsk
# Processing Record 28 of Set 8 | paita
# Processing Record 29 of Set 8 | maniitsoq
# Processing Record 30 of Set 8 | port augusta
# Processing Record 31 of Set 8 | yulara
# Processing Record 32 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 8 | hofn
# Processing Record 34 of Set 8 | pulupandan
# Processing Record 35 of Set 8 | wajima
# Processing Record 36 of Set 8 | dnestrovsc
# Processing Record 37 of Set 8 | biak
# Processing Record 38 of Set 8 | bam
# Processing Record 39 of Set 8 | tacoronte
# Processing Record 40 of Set 8 | otavi
# Processing Record 41 of Set 8 | adrar
# Processing Record 42 of Set 8 | srednekolymsk
# Processing Record 43 of Set 8 | belmonte
# Processing Record 44 of Set 8 | san cristobal
# Processing Record 45 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 46 of Set 8 | callaway
# Processing Record 47 of Set 8 | birao
# Processing Record 48 of Set 8 | itoman
# Processing Record 49 of Set 8 | uch
# Processing Record 0 of Set 9 | santona
# Processing Record 1 of Set 9 | onguday
# Processing Record 2 of Set 9 | hangu
# Processing Record 3 of Set 9 | geraldton
# Processing Record 4 of Set 9 | gorele
# Processing Record 5 of Set 9 | erenhot
# Processing Record 6 of Set 9 | hauterive
# Processing Record 7 of Set 9 | kerema
# Processing Record 8 of Set 9 | jalu
# Processing Record 9 of Set 9 | inhambane
# Processing Record 10 of Set 9 | kenai
# Processing Record 11 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 9 | joshimath
# Processing Record 13 of Set 9 | hamilton
# Processing Record 14 of Set 9 | talnakh
# Processing Record 15 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 16 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | victoria
# Processing Record 19 of Set 9 | atbasar
# Processing Record 20 of Set 9 | bulembu
# Processing Record 21 of Set 9 | hohhot
# Processing Record 22 of Set 9 | halifax
# Processing Record 23 of Set 9 | rehoboth
# Processing Record 24 of Set 9 | beloha
# Processing Record 25 of Set 9 | sehithwa
# Processing Record 26 of Set 9 | burdur
# Processing Record 27 of Set 9 | baruun-urt
# Processing Record 28 of Set 9 | fagernes
# Processing Record 29 of Set 9 | domoni
# City not found. Skipping...
# Processing Record 30 of Set 9 | toyooka
# Processing Record 31 of Set 9 | nantucket
# Processing Record 32 of Set 9 | martaban
# Processing Record 33 of Set 9 | puerto escondido
# Processing Record 34 of Set 9 | port moresby
# Processing Record 35 of Set 9 | malinovskiy
# Processing Record 36 of Set 9 | kumluca
# Processing Record 37 of Set 9 | salinas
# Processing Record 38 of Set 9 | mount isa
# Processing Record 39 of Set 9 | cherskiy
# Processing Record 40 of Set 9 | gobabis
# Processing Record 41 of Set 9 | bilma
# Processing Record 42 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 43 of Set 9 | fort nelson
# Processing Record 44 of Set 9 | quesnel
# Processing Record 45 of Set 9 | dakar
# Processing Record 46 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 9 | santiago del estero
# Processing Record 48 of Set 9 | buala
# Processing Record 49 of Set 9 | irbeyskoye
# Processing Record 0 of Set 10 | vila franca do campo
# Processing Record 1 of Set 10 | coihaique
# Processing Record 2 of Set 10 | los llanos de aridane
# Processing Record 3 of Set 10 | muros
# Processing Record 4 of Set 10 | port hedland
# Processing Record 5 of Set 10 | kieta
# Processing Record 6 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 10 | green river
# Processing Record 8 of Set 10 | mosonmagyarovar
# Processing Record 9 of Set 10 | mindelo
# Processing Record 10 of Set 10 | roblin
# Processing Record 11 of Set 10 | la ronge
# Processing Record 12 of Set 10 | tubuala
# Processing Record 13 of Set 10 | port-gentil
# Processing Record 14 of Set 10 | mordovo
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 10 | aykhal
# Processing Record 18 of Set 10 | tuensang
# Processing Record 19 of Set 10 | pascagoula
# Processing Record 20 of Set 10 | korla
# City not found. Skipping...
# Processing Record 21 of Set 10 | canto do buriti
# Processing Record 22 of Set 10 | bijie
# Processing Record 23 of Set 10 | san-pedro
# Processing Record 24 of Set 10 | luorong
# Processing Record 25 of Set 10 | yei
# City not found. Skipping...
# Processing Record 26 of Set 10 | berlevag
# Processing Record 27 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 10 | satipo
# Processing Record 29 of Set 10 | rawson
# Processing Record 30 of Set 10 | marsh harbour
# Processing Record 31 of Set 10 | taupo
# Processing Record 32 of Set 10 | san carlos de bariloche
# Processing Record 33 of Set 10 | pervomayskoye
# Processing Record 34 of Set 10 | chicama
# Processing Record 35 of Set 10 | angoche
# Processing Record 36 of Set 10 | brae
# Processing Record 37 of Set 10 | manokwari
# Processing Record 38 of Set 10 | mauganj
# Processing Record 39 of Set 10 | te anau
# Processing Record 40 of Set 10 | vila velha
# Processing Record 41 of Set 10 | tautira
# Processing Record 42 of Set 10 | dong xoai
# Processing Record 43 of Set 10 | batemans bay
# Processing Record 44 of Set 10 | diapaga
# Processing Record 45 of Set 10 | mangrol
# Processing Record 46 of Set 10 | mersing
# Processing Record 47 of Set 10 | maldonado
# Processing Record 48 of Set 10 | mikhaylovka
# Processing Record 49 of Set 10 | temple
# Processing Record 0 of Set 11 | gigmoto
# Processing Record 1 of Set 11 | makow mazowiecki
# Processing Record 2 of Set 11 | lasa
# Processing Record 3 of Set 11 | mazamari
# Processing Record 4 of Set 11 | matagami
# Processing Record 5 of Set 11 | steamboat springs
# Processing Record 6 of Set 11 | mount gambier
# Processing Record 7 of Set 11 | chyhyryn
# Processing Record 8 of Set 11 | nortelandia
# Processing Record 9 of Set 11 | imperial
# Processing Record 10 of Set 11 | progreso
# Processing Record 11 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 12 of Set 11 | arriaga
# Processing Record 13 of Set 11 | qusar
# Processing Record 14 of Set 11 | tessalit
# Processing Record 15 of Set 11 | de aar
# Processing Record 16 of Set 11 | kutum
# Processing Record 17 of Set 11 | ketchikan
# Processing Record 18 of Set 11 | peleduy
# Processing Record 19 of Set 11 | libenge
# Processing Record 20 of Set 11 | kapoeta
# City not found. Skipping...
# Processing Record 21 of Set 11 | tomatlan
# Processing Record 22 of Set 11 | lalmohan
# Processing Record 23 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 24 of Set 11 | serowe
# Processing Record 25 of Set 11 | mihail kogalniceanu
# Processing Record 26 of Set 11 | broken hill
# Processing Record 27 of Set 11 | ajaccio
# Processing Record 28 of Set 11 | suntar
# Processing Record 29 of Set 11 | mezica
# Processing Record 30 of Set 11 | sitka
# Processing Record 31 of Set 11 | ewa beach
# Processing Record 32 of Set 11 | songea
# Processing Record 33 of Set 11 | monroe
# Processing Record 34 of Set 11 | cravo norte
# Processing Record 35 of Set 11 | ystad
# Processing Record 36 of Set 11 | beyneu
# Processing Record 37 of Set 11 | almaznyy
# Processing Record 38 of Set 11 | vestmannaeyjar
# Processing Record 39 of Set 11 | cananeia
# Processing Record 40 of Set 11 | alta floresta
# Processing Record 41 of Set 11 | maketu
# Processing Record 42 of Set 11 | mecca
# Processing Record 43 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 44 of Set 11 | manta
# Processing Record 45 of Set 11 | nebug
# Processing Record 46 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 11 | constitucion
# Processing Record 48 of Set 11 | cabimas
# Processing Record 49 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 0 of Set 12 | khudumelapye
# Processing Record 1 of Set 12 | husavik
# Processing Record 2 of Set 12 | olinda
# Processing Record 3 of Set 12 | coquimbo
# Processing Record 4 of Set 12 | kambove
# Processing Record 5 of Set 12 | iquique
# Processing Record 6 of Set 12 | yenagoa
# Processing Record 7 of Set 12 | konakovo
# Processing Record 8 of Set 12 | labuhan
# Processing Record 9 of Set 12 | sampit
# Processing Record 10 of Set 12 | gayny
# Processing Record 11 of Set 12 | trafaria
# Processing Record 12 of Set 12 | zyryanka
# Processing Record 13 of Set 12 | soavinandriana
# Processing Record 14 of Set 12 | xiongzhou
# Processing Record 15 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 12 | batamshinskiy
# Processing Record 18 of Set 12 | kailua
# Processing Record 19 of Set 12 | kaliyaganj
# Processing Record 20 of Set 12 | cozumel
# City not found. Skipping...
# Processing Record 21 of Set 12 | obo
# Processing Record 22 of Set 12 | mushie
# Processing Record 23 of Set 12 | ishigaki
# Processing Record 24 of Set 12 | newport
# Processing Record 25 of Set 12 | quang ngai
# Processing Record 26 of Set 12 | butembo
# Processing Record 27 of Set 12 | palmer
# Processing Record 28 of Set 12 | motril
# Processing Record 29 of Set 12 | patitirion
# Processing Record 30 of Set 12 | omboue
# Processing Record 31 of Set 12 | waipawa
# Processing Record 32 of Set 12 | sakaiminato
# Processing Record 33 of Set 12 | raga
# City not found. Skipping...
# Processing Record 34 of Set 12 | xingcheng
# Processing Record 35 of Set 12 | necochea
# Processing Record 36 of Set 12 | gao
# Processing Record 37 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 39 of Set 12 | jiwani
# Processing Record 40 of Set 12 | yurla
# Processing Record 41 of Set 12 | codrington
# Processing Record 42 of Set 12 | kalmunai
# Processing Record 43 of Set 12 | flinders
# Processing Record 44 of Set 12 | primorsko-akhtarsk
# Processing Record 45 of Set 12 | ilulissat
# Processing Record 46 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 12 | isfana
# Processing Record 48 of Set 12 | borshchiv
# Processing Record 49 of Set 12 | hobyo
# Processing Record 0 of Set 13 | aktash
# City not found. Skipping...
# Processing Record 1 of Set 13 | syamzha
# Processing Record 2 of Set 13 | mahibadhoo
# Processing Record 3 of Set 13 | tiznit
# Processing Record 4 of Set 13 | point fortin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_data_df = pd.DataFrame({ "City": city,
                                "Country": country,
                               "Latitude": lat,
                               "Longitude": lon,
                               "Weather": weather,
                               "Temperature": temp,
                               "Humidity": humidity,
                               "Wind Speed": wind,
                               "Cloud Cover %": clouds})

weather_data_df.to_csv('cities.csv')

weather_data_df.head()
# Out:
#           City Country  Latitude  Longitude Weather  Temperature  Humidity  \
# 0      Rikitea      PF    -23.12    -134.97   Clear        75.63        77
# 1    Hithadhoo      MV     -0.60      73.08    Rain        81.28        79
# 2  Henties Bay      NA    -22.12      14.28  Clouds        61.00        93
# 3         Asău      RO     46.43      26.40  Clouds        42.75        52
# 4       Phayao      TH     19.25     100.25    Rain        93.22        29
#
#    Wind Speed  Cloud Cover %
# 0       18.41              8
# 1        9.28             98
# 2        3.31             13
# 3        5.82             83
# 4        5.95             22

# %%
### Convert Raw Data to DataFrame
* Export the city data into a .csv.
* Display the DataFrame
# Out:
# City          535
# Cloudiness    535
# Country       535
# Date          535
# Humidity      535
# Lat           535
# Lng           535
# Max Temp      535
# Wind Speed    535
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Scatter plot Latitude vs. Tempreture 

x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Temperature"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Max Temperature (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Humidity"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 300)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Humidity (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Cloud Cover %"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Cloudiness (%) (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Wind Speed"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-5, 60)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Wind Speed (mph) (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_data_df.head()

north = weather_data_df[weather_data_df["Latitude"] > 0]
south = weather_data_df[weather_data_df["Latitude"] < 0]

south.head()
# Out:
#                City Country  Latitude  Longitude Weather  Temperature  \
# 0           Rikitea      PF    -23.12    -134.97   Clear        75.63
# 1         Hithadhoo      MV     -0.60      73.08    Rain        81.28
# 2       Henties Bay      NA    -22.12      14.28  Clouds        61.00
# 12  Bambous Virieux      MU    -20.34      57.76  Clouds        76.53
# 13         Hermanus      ZA    -34.42      19.23  Clouds        61.00
#
#     Humidity  Wind Speed  Cloud Cover %
# 0         77       18.41              8
# 1         79        9.28             98
# 2         93        3.31             13
# 12        74        3.36             40
# 13        96        8.75             99

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Temperature"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Max Temperature (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.9232930082744913

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Temperature"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(35, 100)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,70),fontsize=15,color="red")

plt.title("City Latitudes vs. Max Temperature (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.6707758527341177

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Humidity"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Humidity (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.2656518556165464

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Humidity"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(20, 105)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,70),fontsize=15,color="red")

plt.title("City Latitudes vs. Humidity (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.21378343955622656

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Cloud Cover %"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Cloudiness (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.17129319761190093

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Cloud Cover %"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-4, 105)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,70),fontsize=15,color="red")

plt.title("City Latitudes vs. Cloudiness (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.07761179432597227

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Wind Speed"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-2, 60)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Wind Speed (mph) (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.2959874343393372

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Wind Speed"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-2, 30)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,15),fontsize=15,color="red")

plt.title("City Latitudes vs. Wind Speed (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.3758297092723833

# %%
# Out:
# The r-squared is: -0.322483077139538
