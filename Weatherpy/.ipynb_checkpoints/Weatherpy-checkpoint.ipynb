# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# - Observations
#     * The further you get away from the equator, the lower the temps generally are.
#     * Humidity, wind speed, and cloud cover are not correlated with latitude according to the scatter       plots.
#     * The northern and southern hemispheres seem to mirror each other.

# %%
#pip install citipy
#pip install openweathermapy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import json
from scipy.stats import linregress

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
response_json = []
city = []
country = []
coords = []
lat = []
lon = []
weather_list = []
weather = []
temp = []
humidity = []
wind = []
clouds = []
city_count = 0


url = "https://api.openweathermap.org/data/2.5/weather?q="

for x in (cities):
    city_count = city_count + 1
    print(f"Fetching weather data for city {city_count} {x}")
          
    post_response = requests.get(url + x + "&units=imperial&appid=" + api_key).json()
    
    try:
        city.append(post_response['name'])
        country.append(post_response['sys']['country'])
        coords.append(post_response['coord'])
        lat.append(post_response['coord']['lat'])
        lon.append(post_response['coord']['lon'])
        weather.append(post_response['weather'][0]['main'])
        temp.append(post_response['main']['temp'])
        humidity.append(post_response['main']['humidity'])
        wind.append(post_response['wind']['speed'])
        clouds.append(post_response['clouds']['all'])
  
    except KeyError: 
        print("Cannot find city")
# Out:
# Fetching weather data for city 1 kazalinsk
# Cannot find city
# Fetching weather data for city 2 sambava
# Fetching weather data for city 3 chuy
# Fetching weather data for city 4 belushya guba
# Cannot find city
# Fetching weather data for city 5 tasiilaq
# Fetching weather data for city 6 yellowknife
# Fetching weather data for city 7 komsomolskiy
# Fetching weather data for city 8 westport
# Fetching weather data for city 9 mataura
# Fetching weather data for city 10 upernavik
# Fetching weather data for city 11 ilulissat
# Fetching weather data for city 12 nhulunbuy
# Fetching weather data for city 13 plouzane
# Fetching weather data for city 14 kaitangata
# Fetching weather data for city 15 grand river south east
# Cannot find city
# Fetching weather data for city 16 port alfred
# Fetching weather data for city 17 narsaq
# Fetching weather data for city 18 pevek
# Fetching weather data for city 19 busselton
# Fetching weather data for city 20 caborca
# Fetching weather data for city 21 lakatoro
# Fetching weather data for city 22 sao filipe
# Fetching weather data for city 23 yar-sale
# Fetching weather data for city 24 rikitea
# Fetching weather data for city 25 albany
# Fetching weather data for city 26 fairbanks
# Fetching weather data for city 27 kokkarion
# Fetching weather data for city 28 bengkulu
# Fetching weather data for city 29 jibuti
# Fetching weather data for city 30 illoqqortoormiut
# Cannot find city
# Fetching weather data for city 31 butaritari
# Fetching weather data for city 32 mar del plata
# Fetching weather data for city 33 mercedes
# Fetching weather data for city 34 royan
# Fetching weather data for city 35 margate
# Fetching weather data for city 36 hobart
# Fetching weather data for city 37 hithadhoo
# Fetching weather data for city 38 mount gambier
# Fetching weather data for city 39 taolanaro
# Cannot find city
# Fetching weather data for city 40 alice springs
# Fetching weather data for city 41 rio grande
# Fetching weather data for city 42 dingle
# Fetching weather data for city 43 tsihombe
# Cannot find city
# Fetching weather data for city 44 dalvik
# Fetching weather data for city 45 ushuaia
# Fetching weather data for city 46 mitu
# Fetching weather data for city 47 zambezi
# Fetching weather data for city 48 port-cartier
# Fetching weather data for city 49 bluff
# Fetching weather data for city 50 taoudenni
# Fetching weather data for city 51 attawapiskat
# Cannot find city
# Fetching weather data for city 52 talcahuano
# Fetching weather data for city 53 clyde river
# Fetching weather data for city 54 arraial do cabo
# Fetching weather data for city 55 marcona
# Cannot find city
# Fetching weather data for city 56 cabo san lucas
# Fetching weather data for city 57 sisimiut
# Fetching weather data for city 58 dakar
# Fetching weather data for city 59 varzob
# Fetching weather data for city 60 thompson
# Fetching weather data for city 61 punta arenas
# Fetching weather data for city 62 conde
# Fetching weather data for city 63 kapaa
# Fetching weather data for city 64 emba
# Fetching weather data for city 65 castro
# Fetching weather data for city 66 diego de almagro
# Fetching weather data for city 67 erzurum
# Fetching weather data for city 68 acapulco
# Fetching weather data for city 69 bashtanka
# Fetching weather data for city 70 oxapampa
# Fetching weather data for city 71 saint-gilles
# Fetching weather data for city 72 halifax
# Fetching weather data for city 73 san patricio
# Fetching weather data for city 74 bethel
# Fetching weather data for city 75 general roca
# Fetching weather data for city 76 provideniya
# Fetching weather data for city 77 cidreira
# Fetching weather data for city 78 maldonado
# Fetching weather data for city 79 hermanus
# Fetching weather data for city 80 nome
# Fetching weather data for city 81 pangkalanbuun
# Fetching weather data for city 82 houston
# Fetching weather data for city 83 bredasdorp
# Fetching weather data for city 84 saint anthony
# Fetching weather data for city 85 new norfolk
# Fetching weather data for city 86 nikolskoye
# Fetching weather data for city 87 salalah
# Fetching weather data for city 88 port elizabeth
# Fetching weather data for city 89 lompoc
# Fetching weather data for city 90 maragogi
# Fetching weather data for city 91 faya
# Fetching weather data for city 92 lom sak
# Fetching weather data for city 93 hilo
# Fetching weather data for city 94 cam ranh
# Fetching weather data for city 95 east london
# Fetching weather data for city 96 trani
# Fetching weather data for city 97 ancud
# Fetching weather data for city 98 port hardy
# Fetching weather data for city 99 mudgee
# Fetching weather data for city 100 puerto ayora
# Fetching weather data for city 101 kruisfontein
# Fetching weather data for city 102 marsh harbour
# Fetching weather data for city 103 odweyne
# Fetching weather data for city 104 san cristobal
# Fetching weather data for city 105 vaini
# Fetching weather data for city 106 port hedland
# Fetching weather data for city 107 machico
# Fetching weather data for city 108 mbandaka
# Fetching weather data for city 109 codrington
# Fetching weather data for city 110 georgetown
# Fetching weather data for city 111 saint-philippe
# Fetching weather data for city 112 braganca paulista
# Fetching weather data for city 113 krasnoselkup
# Fetching weather data for city 114 thinadhoo
# Fetching weather data for city 115 hornepayne
# Fetching weather data for city 116 gimli
# Fetching weather data for city 117 qixingtai
# Fetching weather data for city 118 tiksi
# Fetching weather data for city 119 zlobin
# Fetching weather data for city 120 udachnyy
# Fetching weather data for city 121 kumluca
# Fetching weather data for city 122 akyab
# Fetching weather data for city 123 abu zabad
# Fetching weather data for city 124 tipitapa
# Fetching weather data for city 125 seoul
# Fetching weather data for city 126 rio de janeiro
# Fetching weather data for city 127 gamboma
# Fetching weather data for city 128 saint-pierre
# Fetching weather data for city 129 plettenberg bay
# Fetching weather data for city 130 avarua
# Fetching weather data for city 131 gwembe
# Fetching weather data for city 132 stoyba
# Cannot find city
# Fetching weather data for city 133 jamestown
# Fetching weather data for city 134 bambous virieux
# Fetching weather data for city 135 tabiauea
# Cannot find city
# Fetching weather data for city 136 trairi
# Fetching weather data for city 137 saint george
# Fetching weather data for city 138 finote selam
# Fetching weather data for city 139 kachug
# Fetching weather data for city 140 kodiak
# Fetching weather data for city 141 hobyo
# Fetching weather data for city 142 ponta do sol
# Fetching weather data for city 143 sioux lookout
# Fetching weather data for city 144 lavrentiya
# Fetching weather data for city 145 khatanga
# Fetching weather data for city 146 jiutai
# Fetching weather data for city 147 roseto degli abruzzi
# Fetching weather data for city 148 katima mulilo
# Fetching weather data for city 149 tari
# Fetching weather data for city 150 toliary
# Cannot find city
# Fetching weather data for city 151 mys shmidta
# Cannot find city
# Fetching weather data for city 152 okhotsk
# Fetching weather data for city 153 larnaca
# Fetching weather data for city 154 constitucion
# Fetching weather data for city 155 utiroa
# Cannot find city
# Fetching weather data for city 156 atuona
# Fetching weather data for city 157 verkhniy lomov
# Fetching weather data for city 158 kindu
# Fetching weather data for city 159 souillac
# Fetching weather data for city 160 ende
# Fetching weather data for city 161 airai
# Fetching weather data for city 162 barrow
# Fetching weather data for city 163 vila franca do campo
# Fetching weather data for city 164 ardabil
# Fetching weather data for city 165 north bend
# Fetching weather data for city 166 shache
# Fetching weather data for city 167 sentyabrskiy
# Cannot find city
# Fetching weather data for city 168 bokspits
# Cannot find city
# Fetching weather data for city 169 berlevag
# Fetching weather data for city 170 terrace bay
# Fetching weather data for city 171 saint-louis
# Fetching weather data for city 172 tuktoyaktuk
# Fetching weather data for city 173 khandyga
# Fetching weather data for city 174 cape town
# Fetching weather data for city 175 mahebourg
# Fetching weather data for city 176 longyearbyen
# Fetching weather data for city 177 uyemskiy
# Fetching weather data for city 178 darnah
# Fetching weather data for city 179 santiago de cao
# Fetching weather data for city 180 bilma
# Fetching weather data for city 181 luderitz
# Fetching weather data for city 182 mumford
# Fetching weather data for city 183 gursahaiganj
# Fetching weather data for city 184 namatanai
# Fetching weather data for city 185 porto novo
# Fetching weather data for city 186 port blair
# Fetching weather data for city 187 north platte
# Fetching weather data for city 188 jimenez
# Fetching weather data for city 189 mrirt
# Cannot find city
# Fetching weather data for city 190 vardo
# Fetching weather data for city 191 sitka
# Fetching weather data for city 192 quimper
# Fetching weather data for city 193 axim
# Fetching weather data for city 194 bagotville
# Fetching weather data for city 195 buta
# Fetching weather data for city 196 urdzhar
# Cannot find city
# Fetching weather data for city 197 carnarvon
# Fetching weather data for city 198 surt
# Fetching weather data for city 199 beringovskiy
# Fetching weather data for city 200 nizhneyansk
# Cannot find city
# Fetching weather data for city 201 taltal
# Fetching weather data for city 202 inyonga
# Fetching weather data for city 203 praia da vitoria
# Fetching weather data for city 204 jiddah
# Cannot find city
# Fetching weather data for city 205 lebu
# Fetching weather data for city 206 torbay
# Fetching weather data for city 207 iqaluit
# Fetching weather data for city 208 goderich
# Fetching weather data for city 209 westonaria
# Fetching weather data for city 210 ardakan
# Fetching weather data for city 211 tabas
# Fetching weather data for city 212 dikson
# Fetching weather data for city 213 leningradskiy
# Fetching weather data for city 214 qasigiannguit
# Fetching weather data for city 215 tashtyp
# Fetching weather data for city 216 koutiala
# Fetching weather data for city 217 port shepstone
# Fetching weather data for city 218 savelugu
# Fetching weather data for city 219 pimentel
# Fetching weather data for city 220 whitianga
# Fetching weather data for city 221 coari
# Fetching weather data for city 222 high level
# Fetching weather data for city 223 namibe
# Fetching weather data for city 224 maturin
# Fetching weather data for city 225 fort nelson
# Fetching weather data for city 226 karachi
# Fetching weather data for city 227 saleaula
# Cannot find city
# Fetching weather data for city 228 motygino
# Fetching weather data for city 229 kavieng
# Fetching weather data for city 230 saskylakh
# Fetching weather data for city 231 nanortalik
# Fetching weather data for city 232 yumen
# Fetching weather data for city 233 nabire
# Fetching weather data for city 234 makakilo city
# Fetching weather data for city 235 victoria
# Fetching weather data for city 236 yanan
# Cannot find city
# Fetching weather data for city 237 dunedin
# Fetching weather data for city 238 kontagora
# Fetching weather data for city 239 grand-lahou
# Fetching weather data for city 240 usti
# Cannot find city
# Fetching weather data for city 241 kavaratti
# Fetching weather data for city 242 inuvik
# Fetching weather data for city 243 severo-kurilsk
# Fetching weather data for city 244 sonoita
# Fetching weather data for city 245 manicore
# Fetching weather data for city 246 fortuna
# Fetching weather data for city 247 clarence town
# Fetching weather data for city 248 poum
# Fetching weather data for city 249 hasaki
# Fetching weather data for city 250 solnechnyy
# Fetching weather data for city 251 astoria
# Fetching weather data for city 252 carutapera
# Fetching weather data for city 253 raudeberg
# Fetching weather data for city 254 dharchula
# Fetching weather data for city 255 svetlogorsk
# Fetching weather data for city 256 tanshui
# Cannot find city
# Fetching weather data for city 257 jalu
# Fetching weather data for city 258 zhadovka
# Fetching weather data for city 259 vung tau
# Fetching weather data for city 260 pisco
# Fetching weather data for city 261 fonte boa
# Fetching weather data for city 262 rio gallegos
# Fetching weather data for city 263 san lucas
# Fetching weather data for city 264 goundam
# Fetching weather data for city 265 den helder
# Fetching weather data for city 266 lagoa
# Fetching weather data for city 267 swan river
# Fetching weather data for city 268 katobu
# Fetching weather data for city 269 puri
# Fetching weather data for city 270 juneau
# Fetching weather data for city 271 tasbuget
# Cannot find city
# Fetching weather data for city 272 los llanos de aridane
# Fetching weather data for city 273 ipixuna
# Fetching weather data for city 274 vaitape
# Fetching weather data for city 275 rydultowy
# Fetching weather data for city 276 abu samrah
# Fetching weather data for city 277 santa marta
# Fetching weather data for city 278 sobrance
# Fetching weather data for city 279 banfora
# Fetching weather data for city 280 oranjemund
# Fetching weather data for city 281 pangnirtung
# Fetching weather data for city 282 svetlyy
# Fetching weather data for city 283 auchi
# Fetching weather data for city 284 suntar
# Fetching weather data for city 285 ternate
# Fetching weather data for city 286 salihorsk
# Fetching weather data for city 287 chokurdakh
# Fetching weather data for city 288 pundaguitan
# Fetching weather data for city 289 goksun
# Fetching weather data for city 290 hualmay
# Fetching weather data for city 291 cudahy
# Fetching weather data for city 292 digby
# Fetching weather data for city 293 qaanaaq
# Fetching weather data for city 294 pontalina
# Fetching weather data for city 295 wick
# Fetching weather data for city 296 grindavik
# Fetching weather data for city 297 chicama
# Fetching weather data for city 298 boa vista
# Fetching weather data for city 299 meyungs
# Cannot find city
# Fetching weather data for city 300 hambantota
# Fetching weather data for city 301 havre-saint-pierre
# Fetching weather data for city 302 lorengau
# Fetching weather data for city 303 ribeira grande
# Fetching weather data for city 304 isangel
# Fetching weather data for city 305 nouadhibou
# Fetching weather data for city 306 goure
# Fetching weather data for city 307 pokosnoye
# Fetching weather data for city 308 bolivar
# Fetching weather data for city 309 prince rupert
# Fetching weather data for city 310 charters towers
# Fetching weather data for city 311 half moon bay
# Fetching weather data for city 312 panaba
# Fetching weather data for city 313 gouyave
# Fetching weather data for city 314 talnakh
# Fetching weather data for city 315 ukiah
# Fetching weather data for city 316 owo
# Fetching weather data for city 317 porosozero
# Fetching weather data for city 318 inta
# Fetching weather data for city 319 ossora
# Fetching weather data for city 320 aksarka
# Fetching weather data for city 321 bonthe
# Fetching weather data for city 322 maltahohe
# Fetching weather data for city 323 wuda
# Fetching weather data for city 324 hay river
# Fetching weather data for city 325 granada
# Fetching weather data for city 326 rawson
# Fetching weather data for city 327 panguna
# Fetching weather data for city 328 godalming
# Fetching weather data for city 329 tual
# Fetching weather data for city 330 walvis bay
# Fetching weather data for city 331 quatre cocos
# Fetching weather data for city 332 nove mesto na morave
# Fetching weather data for city 333 nizwa
# Fetching weather data for city 334 garden city
# Fetching weather data for city 335 haines junction
# Fetching weather data for city 336 kautokeino
# Fetching weather data for city 337 glace bay
# Fetching weather data for city 338 tuatapere
# Fetching weather data for city 339 amderma
# Cannot find city
# Fetching weather data for city 340 ahipara
# Fetching weather data for city 341 kleive
# Fetching weather data for city 342 broome
# Fetching weather data for city 343 wattegama
# Fetching weather data for city 344 jaciara
# Fetching weather data for city 345 cabra
# Fetching weather data for city 346 kassala
# Fetching weather data for city 347 vao
# Fetching weather data for city 348 haapiti
# Fetching weather data for city 349 hamilton
# Fetching weather data for city 350 simpang
# Fetching weather data for city 351 trat
# Fetching weather data for city 352 ocos
# Fetching weather data for city 353 irondequoit
# Fetching weather data for city 354 auburn
# Fetching weather data for city 355 karaul
# Cannot find city
# Fetching weather data for city 356 qurayyat
# Fetching weather data for city 357 fukue
# Fetching weather data for city 358 mackay
# Fetching weather data for city 359 aksha
# Fetching weather data for city 360 la ronge
# Fetching weather data for city 361 opuwo
# Fetching weather data for city 362 barentsburg
# Cannot find city
# Fetching weather data for city 363 klaksvik
# Fetching weather data for city 364 mocuba
# Fetching weather data for city 365 senneterre
# Fetching weather data for city 366 labuhan
# Fetching weather data for city 367 skibbereen
# Fetching weather data for city 368 mossendjo
# Fetching weather data for city 369 tommot
# Fetching weather data for city 370 lata
# Fetching weather data for city 371 umzimvubu
# Cannot find city
# Fetching weather data for city 372 malyye derbety
# Fetching weather data for city 373 winnemucca
# Fetching weather data for city 374 tawnat
# Cannot find city
# Fetching weather data for city 375 laibin
# Fetching weather data for city 376 mindelo
# Fetching weather data for city 377 bugene
# Fetching weather data for city 378 basay
# Fetching weather data for city 379 paamiut
# Fetching weather data for city 380 rudnogorsk
# Fetching weather data for city 381 el seibo
# Fetching weather data for city 382 wanning
# Fetching weather data for city 383 neuquen
# Fetching weather data for city 384 aquiraz
# Fetching weather data for city 385 tahoua
# Fetching weather data for city 386 baykit
# Fetching weather data for city 387 tiarei
# Fetching weather data for city 388 eureka
# Fetching weather data for city 389 baturaden
# Fetching weather data for city 390 masindi
# Fetching weather data for city 391 vaitupu
# Cannot find city
# Fetching weather data for city 392 trinidad
# Fetching weather data for city 393 esperance
# Fetching weather data for city 394 dauphin
# Fetching weather data for city 395 yei
# Fetching weather data for city 396 antofagasta
# Fetching weather data for city 397 grao mogol
# Fetching weather data for city 398 sao felix do xingu
# Fetching weather data for city 399 portalegre
# Fetching weather data for city 400 bendigo
# Fetching weather data for city 401 hradek
# Fetching weather data for city 402 penarroya-pueblonuevo
# Fetching weather data for city 403 olafsvik
# Fetching weather data for city 404 mehriz
# Fetching weather data for city 405 mill valley
# Fetching weather data for city 406 yarkovo
# Fetching weather data for city 407 kathmandu
# Fetching weather data for city 408 kloulklubed
# Fetching weather data for city 409 valparaiso
# Fetching weather data for city 410 samusu
# Cannot find city
# Fetching weather data for city 411 maceio
# Fetching weather data for city 412 wonthaggi
# Fetching weather data for city 413 cockburn town
# Fetching weather data for city 414 nador
# Fetching weather data for city 415 wanaka
# Fetching weather data for city 416 doha
# Fetching weather data for city 417 ayan
# Fetching weather data for city 418 dunnville
# Fetching weather data for city 419 port hawkesbury
# Fetching weather data for city 420 mbini
# Fetching weather data for city 421 ashtian
# Fetching weather data for city 422 canavieiras
# Fetching weather data for city 423 tautira
# Fetching weather data for city 424 ulagan
# Fetching weather data for city 425 cabuyaro
# Fetching weather data for city 426 husavik
# Fetching weather data for city 427 buariki
# Cannot find city
# Fetching weather data for city 428 geraldton
# Fetching weather data for city 429 naron
# Fetching weather data for city 430 denpasar
# Fetching weather data for city 431 grand gaube
# Fetching weather data for city 432 aguimes
# Fetching weather data for city 433 touros
# Fetching weather data for city 434 ahuimanu
# Fetching weather data for city 435 sao lourenco da serra
# Fetching weather data for city 436 mucurapo
# Fetching weather data for city 437 xiongzhou
# Fetching weather data for city 438 sao joao da barra
# Fetching weather data for city 439 naze
# Fetching weather data for city 440 cayenne
# Fetching weather data for city 441 aykhal
# Fetching weather data for city 442 ocean city
# Fetching weather data for city 443 hauterive
# Fetching weather data for city 444 idanre
# Fetching weather data for city 445 san policarpo
# Fetching weather data for city 446 santa cruz
# Fetching weather data for city 447 banda aceh
# Fetching weather data for city 448 xifeng
# Fetching weather data for city 449 te anau
# Fetching weather data for city 450 katsuura
# Fetching weather data for city 451 ziro
# Fetching weather data for city 452 daxian
# Cannot find city
# Fetching weather data for city 453 mogadishu
# Fetching weather data for city 454 sao jose de ribamar
# Fetching weather data for city 455 ruwi
# Fetching weather data for city 456 vilhena
# Fetching weather data for city 457 fortaleza
# Fetching weather data for city 458 honningsvag
# Fetching weather data for city 459 thilogne
# Cannot find city
# Fetching weather data for city 460 mao
# Fetching weather data for city 461 noumea
# Fetching weather data for city 462 deputatskiy
# Fetching weather data for city 463 louisbourg
# Cannot find city
# Fetching weather data for city 464 ostrovnoy
# Fetching weather data for city 465 kizner
# Fetching weather data for city 466 norman wells
# Fetching weather data for city 467 marzuq
# Fetching weather data for city 468 kralendijk
# Fetching weather data for city 469 yulara
# Fetching weather data for city 470 khash
# Fetching weather data for city 471 cariamanga
# Fetching weather data for city 472 bireun
# Fetching weather data for city 473 kahului
# Fetching weather data for city 474 deh rawud
# Cannot find city
# Fetching weather data for city 475 salym
# Fetching weather data for city 476 kisangani
# Fetching weather data for city 477 celestun
# Fetching weather data for city 478 dombarovskiy
# Fetching weather data for city 479 alofi
# Fetching weather data for city 480 beloha
# Fetching weather data for city 481 mecca
# Fetching weather data for city 482 sistranda
# Fetching weather data for city 483 kuandian
# Fetching weather data for city 484 sur
# Fetching weather data for city 485 najran
# Fetching weather data for city 486 gambela
# Fetching weather data for city 487 acajutla
# Fetching weather data for city 488 vostok
# Fetching weather data for city 489 mount isa
# Fetching weather data for city 490 progreso
# Fetching weather data for city 491 stettler
# Fetching weather data for city 492 mehran
# Fetching weather data for city 493 the valley
# Fetching weather data for city 494 talara
# Fetching weather data for city 495 kurayoshi
# Fetching weather data for city 496 garowe
# Fetching weather data for city 497 stornoway
# Fetching weather data for city 498 rongcheng
# Fetching weather data for city 499 borogontsy
# Fetching weather data for city 500 ranau
# Fetching weather data for city 501 tuggurt
# Cannot find city
# Fetching weather data for city 502 puerto santander
# Fetching weather data for city 503 veraval
# Fetching weather data for city 504 camacha
# Fetching weather data for city 505 sabinopolis
# Fetching weather data for city 506 pampas
# Fetching weather data for city 507 sechura
# Fetching weather data for city 508 zhigansk
# Fetching weather data for city 509 manokwari
# Fetching weather data for city 510 ixtapa
# Fetching weather data for city 511 burns lake
# Fetching weather data for city 512 bud
# Fetching weather data for city 513 oksfjord
# Fetching weather data for city 514 huron
# Fetching weather data for city 515 kudahuvadhoo
# Fetching weather data for city 516 bardiyah
# Fetching weather data for city 517 bukama
# Fetching weather data for city 518 kingsport
# Fetching weather data for city 519 cherskiy
# Fetching weather data for city 520 iracoubo
# Fetching weather data for city 521 palmer
# Fetching weather data for city 522 barentu
# Fetching weather data for city 523 richards bay
# Fetching weather data for city 524 moose factory
# Fetching weather data for city 525 tagusao
# Fetching weather data for city 526 japura
# Fetching weather data for city 527 centerville
# Fetching weather data for city 528 sinjai
# Fetching weather data for city 529 verkhnevilyuysk
# Fetching weather data for city 530 nalut
# Fetching weather data for city 531 comodoro rivadavia
# Fetching weather data for city 532 at-bashi
# Fetching weather data for city 533 tawkar
# Cannot find city
# Fetching weather data for city 534 letlhakane
# Fetching weather data for city 535 ouahigouya
# Fetching weather data for city 536 xining
# Fetching weather data for city 537 plover
# Fetching weather data for city 538 diffa
# Fetching weather data for city 539 west wendover
# Fetching weather data for city 540 kenmare
# Fetching weather data for city 541 manggar
# Fetching weather data for city 542 bayir
# Fetching weather data for city 543 muisne
# Fetching weather data for city 544 erzin
# Fetching weather data for city 545 sorland
# Fetching weather data for city 546 idukki
# Fetching weather data for city 547 ulladulla
# Fetching weather data for city 548 ketchikan
# Fetching weather data for city 549 kashan
# Fetching weather data for city 550 aasiaat
# Fetching weather data for city 551 sinnamary
# Fetching weather data for city 552 ust-uda
# Fetching weather data for city 553 tokat
# Fetching weather data for city 554 campbell river
# Fetching weather data for city 555 laguna
# Fetching weather data for city 556 shingu
# Fetching weather data for city 557 canete
# Fetching weather data for city 558 poltavka
# Fetching weather data for city 559 savannah bight
# Fetching weather data for city 560 barra do corda
# Fetching weather data for city 561 kalmunai
# Fetching weather data for city 562 iringa
# Fetching weather data for city 563 tzaneen
# Fetching weather data for city 564 birao
# Fetching weather data for city 565 lazarev
# Fetching weather data for city 566 ensenada
# Fetching weather data for city 567 krapina
# Fetching weather data for city 568 cairns
# Fetching weather data for city 569 abu kamal
# Fetching weather data for city 570 saint-francois
# Fetching weather data for city 571 lethem
# Fetching weather data for city 572 pinega
# Fetching weather data for city 573 dali
# Fetching weather data for city 574 hachinohe
# Fetching weather data for city 575 bolungarvik
# Cannot find city
# Fetching weather data for city 576 charleston
# Fetching weather data for city 577 new glasgow
# Fetching weather data for city 578 poronaysk
# Fetching weather data for city 579 dudinka
# Fetching weather data for city 580 samarai
# Fetching weather data for city 581 guerrero negro
# Fetching weather data for city 582 bajna
# Fetching weather data for city 583 liberia
# Fetching weather data for city 584 ballina
# Fetching weather data for city 585 bahia blanca
# Fetching weather data for city 586 oriximina
# Fetching weather data for city 587 santa rosa
# Fetching weather data for city 588 shelburne
# Fetching weather data for city 589 aginskoye
# Fetching weather data for city 590 qax
# Fetching weather data for city 591 flin flon
# Fetching weather data for city 592 moerai
# Fetching weather data for city 593 tunxi
# Cannot find city
# Fetching weather data for city 594 maryborough
# Fetching weather data for city 595 jieshi
# Fetching weather data for city 596 mayo
# Fetching weather data for city 597 middelburg
# Fetching weather data for city 598 turukhansk
# Fetching weather data for city 599 ahumada
# Cannot find city
# Fetching weather data for city 600 sujiatun
# Fetching weather data for city 601 avera
# Fetching weather data for city 602 sao geraldo do araguaia
# Fetching weather data for city 603 sorong
# Fetching weather data for city 604 puerto del rosario
# Fetching weather data for city 605 raga
# Fetching weather data for city 606 karamea
# Cannot find city
# Fetching weather data for city 607 beoumi
# Fetching weather data for city 608 palmira
# Fetching weather data for city 609 aleksandrov gay
# Fetching weather data for city 610 san quintin
# Fetching weather data for city 611 srednekolymsk
# Fetching weather data for city 612 kabo
# Fetching weather data for city 613 inirida
# Fetching weather data for city 614 zhangye
# Fetching weather data for city 615 boali
# Fetching weather data for city 616 caravelas
# Fetching weather data for city 617 kenai
# Fetching weather data for city 618 boca do acre
# Fetching weather data for city 619 riyadh
# Fetching weather data for city 620 hunza
# Cannot find city
# Fetching weather data for city 621 maumere

# %%
weather_data_df = pd.DataFrame({ "City": city,
                                "Country": country,
                               "Latitude": lat,
                               "Longitude": lon,
                               "Weather": weather,
                               "Temperature": temp,
                               "Humidity": humidity,
                               "Wind Speed": wind,
                               "Cloud Cover %": clouds})

#Writing to CSV without index. 
weather_data_df.to_csv('cities.csv', index = False)

weather_data_df.head()
# Out:
#               City Country  Latitude  Longitude Weather  Temperature  \
# 0          Sambava      MG    -14.27      50.17    Rain        75.90
# 1             Chui      UY    -33.70     -53.46   Clear        64.87
# 2         Tasiilaq      GL     65.61     -37.64  Clouds        23.00
# 3      Yellowknife      CA     62.46    -114.35  Clouds        17.37
# 4  Yangi Marg`ilon      UZ     40.43      71.72  Clouds        50.00
#
#    Humidity  Wind Speed  Cloud Cover %
# 0        84        7.85             63
# 1        75        7.85              0
# 2        67        3.33             99
# 3        61       18.34             75
# 4        61        2.24            100

# %%
### Convert Raw Data to DataFrame
#* Export the city data into a .csv.
#* Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Scatter plot Latitude vs. Tempreture 

x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Temperature"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Max Temperature (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()
#plt.savefig('images/lat_v_temp')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Humidity"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 300)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Humidity (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid()
plt.show()
#plt.savefig('images/lat_v_hum')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Cloud Cover %"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Cloudiness (%) (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()
#plt.savefig('images/lat_v_cloud')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = weather_data_df["Latitude"]
y_axis = weather_data_df["Wind Speed"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-5, 60)
plt.xlim(-60, 85)
plt.title("City Latitudes vs. Wind Speed (mph) (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
#plt.savefig('images/lat_v_wind')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_data_df.head()

north = weather_data_df[weather_data_df["Latitude"] > 0]
south = weather_data_df[weather_data_df["Latitude"] < 0]

south.head()
# Out:
#           City Country  Latitude  Longitude Weather  Temperature  Humidity  \
# 0      Sambava      MG    -14.27      50.17    Rain        75.90        84
# 1         Chui      UY    -33.70     -53.46   Clear        64.87        75
# 6      Mataura      NZ    -46.19     168.86   Clear        47.07        76
# 9    Nhulunbuy      AU    -12.23     136.77  Clouds        77.00        94
# 11  Kaitangata      NZ    -46.28     169.85   Clear        57.00        76
#
#     Wind Speed  Cloud Cover %
# 0         7.85             63
# 1         7.85              0
# 6         3.44              0
# 9         4.70             75
# 11        0.76              0

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Temperature"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Max Temperature (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_temp_n')
# Out:
# The r-squared is: -0.9119655515716929

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Temperature"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(35, 100)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,70),fontsize=15,color="red")

plt.title("City Latitudes vs. Max Temperature (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_temp_s')
# Out:
# The r-squared is: 0.7388628870538401

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Humidity"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Humidity (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_hum_n')
# Out:
# The r-squared is: 0.2717865246978406

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Humidity"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(20, 105)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,70),fontsize=15,color="red")

plt.title("City Latitudes vs. Humidity (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_hum_s')
# Out:
# The r-squared is: 0.19222357416950622

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Cloud Cover %"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-10, 120)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Cloudiness (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_cloud_n')
# Out:
# The r-squared is: 0.04944922981234881

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Cloud Cover %"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-4, 105)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,70),fontsize=15,color="red")

plt.title("City Latitudes vs. Cloudiness (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_cloud_s')
# Out:
# The r-squared is: 0.22473027051809638

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = north["Latitude"]
y_axis = north["Wind Speed"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-2, 60)
plt.xlim(-2, 85)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(43,55),fontsize=15,color="red")

plt.title("City Latitudes vs. Wind Speed (mph) (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_wind_n')
# Out:
# The r-squared is: 0.18030111977793137

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Inputed data
x_axis = south["Latitude"]
y_axis = south["Wind Speed"]

#Regression line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the graph
plt.scatter(x_axis, y_axis, marker="o", facecolors="teal", edgecolors="black")
plt.ylim(-2, 30)
plt.xlim(-60, 2)

plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,15),fontsize=15,color="red")

plt.title("City Latitudes vs. Wind Speed (4/4/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
print(f"The r-squared is: {rvalue}")
plt.show()
#plt.savefig('images/lat_v_wind_s')
# Out:
# The r-squared is: -0.29400642108758024
