# %%
# Dependencies and Setup
import pandas as pd
import requests
import json
import csv
import os
import gmaps

#Load Google Places API key
from config import gkey

gmaps.configure(api_key=gkey)

# File to Load
cities = "cities.csv"

# Read city data file and store in Pandas Data frames
city_data = pd.read_csv(cities)
city_data.head()
# Out:
#            City Country  Latitude  Longitude Weather  Temperature  Humidity  \
# 0     Cape Town      ZA    -33.93      18.42  Clouds        61.45        87
# 1          Hilo      US     19.73    -155.09    Rain        68.43        88
# 2       Erdenet      MN     49.03     104.08  Clouds        26.13        55
# 3  Norman Wells      CA     65.28    -126.83  Clouds        14.00        72
# 4       Margate      GB     51.38       1.39   Clear        60.87        37
#
#    Wind Speed  Cloud Cover %
# 0       12.75             75
# 1        3.36             90
# 2        7.65            100
# 3       16.11             20
# 4       14.99              0

# %%
# Extract the cities with ideal weather
ideal_temp = city_data[(city_data["Temperature"] >= 60) & (city_data["Temperature"] <= 80)]
no_wind = ideal_temp[ideal_temp["Wind Speed"] < 10]
clear_skys = no_wind[no_wind["Cloud Cover %"] < 10]
clear_skys
# Out:
#               City Country  Latitude  Longitude Weather  Temperature  \
# 11           Kapaa      US     22.08    -159.32   Clear        66.56
# 55            Chui      UY    -33.70     -53.46   Clear        75.76
# 56          Mocuba      MZ    -16.84      36.99   Clear        69.19
# 61        Suclayin      PH     15.76     121.55   Clear        73.44
# 78          Castro      BR    -24.79     -50.01   Clear        78.46
# 160     Hervey Bay      AU    -25.30     152.85   Clear        70.45
# 195         Bhinga      IN     27.72      81.93   Clear        71.01
# 258           Batī      ET     11.18      40.02   Clear        72.68
# 263        Devgarh      IN     25.53      73.90   Clear        78.64
# 279     Rock Sound      BS     24.90     -76.20   Clear        74.17
# 283          Yanam      IN     16.73      82.22   Clear        79.27
# 307           Buin      CL    -33.73     -70.75   Clear        70.41
# 320     Mubārakpur      IN     26.09      83.29   Clear        79.97
# 342      Alabaster      US     33.24     -86.82   Clear        77.13
# 343        Copiapó      CL    -27.37     -70.33   Clear        77.00
# 378        Bāglung      NP     28.27      83.59   Clear        61.18
# 388     Mossamedes      AO    -15.20      12.15   Clear        72.50
# 390           Tura      IN     25.52      90.22   Clear        70.21
# 403         Kāvali      IN     14.92      79.98   Clear        79.30
# 425      Callaguip      PH     18.07     120.49   Clear        77.45
# 451      Siniscola      IT     40.57       9.69   Clear        62.60
# 465         Kailua      US     21.40    -157.74   Clear        69.24
# 479      ‘Āhuimanu      US     21.44    -157.84   Clear        69.19
# 509         Dingle      PH     11.00     122.67    Rain        77.83
# 516        Tsabong      BW    -26.02      22.40   Clear        76.28
# 531         Dhubri      IN     26.03      89.97   Clear        74.80
# 534  Arroio Grande      BR    -32.24     -53.09   Clear        75.15
# 536        Catuday      PH     16.29     119.81    Rain        79.16
#
#      Humidity  Wind Speed  Cloud Cover %
# 11         93        5.82              1
# 55         50        6.78              8
# 56         83        2.91              5
# 61         76        3.53              6
# 78         30        4.45              3
# 160        88        5.82              6
# 195        72        3.00              0
# 258        30        0.83              8
# 263        15        2.98              2
# 279        55        5.35              1
# 283        84        2.98              2
# 307        37        4.70              4
# 320        18        8.05              0
# 342        46        3.36              1
# 343        44        5.82              3
# 378        20        6.64              7
# 388        76        7.31              1
# 390        19        2.04              0
# 403        91        9.89              0
# 425        78        9.10              0
# 451        33        6.93              7
# 465        78        7.14              1
# 479        78        5.03              1
# 509        80        8.66              2
# 516        26        3.69              0
# 531        20        2.35              0
# 534        52        5.17              0
# 536        75        2.30              2

# %%
response_json = []
name = []
vicinity = []

for index, row in clear_skys.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    

    # geocoordinates
    target_coordinates = f"{lat},{lng}"
    target_search = "Hotel"
    target_radius = 5000
    target_type = "hotel"

    # set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": gkey
    }

    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params).json()
    
    try:
        name.append(response_json['results'][0]['name'])
        vincinity.append(response_json["results"][0]["vicinity"])
        
    #response_json.append(response)
    
    except KeyError: 
        print("Cannot find city")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-e6ed19953693> in <module>
#      30
#      31     try:
# ---> 32         name.append(response_json['results'])
#      33         vincinity.append(response_json["results"][0]["vicinity"])
#      34
#
# TypeError: list indices must be integers or slices, not str

# %%
# convert response to json
#response = response.json()

# Print the json (pretty printed)
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "html_attributions": [],
#         "results": [
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.789677,
#                         "lng": -50.0062751
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.78840072010728,
#                             "lng": -50.00494652010727
#                         },
#                         "southwest": {
#                             "lat": -24.79110037989272,
#                             "lng": -50.00764617989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "e2cddbce880380f5a2d18d5d126efe2b038608ef",
#                 "name": "Hotel Buganville Express",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 2848,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/105486276964746813605\">Hotel Buganville Express</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAZhYkbCOmYwTWE1g7jxKmIFZ__rklA_5k6azwLa7ZpaDvcssZjrcM-YnpOFy6Bu6WLJoiuuZmr9K7Aq1_QvG3p5En78z2V8yKoiJGwhLZz2bmg7rNe48Z5c06Gkm5Hbz1EhAiZxP1iJHrZxh5EH5bEZJMGhTBlYjetIC61kF6SimvQh8TjeKH_A",
#                         "width": 4113
#                     }
#                 ],
#                 "place_id": "ChIJUezZyk2dwpQR1ZjJnd7AD1c",
#                 "plus_code": {
#                     "compound_code": "6X6V+4F Centro, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F6X6V+4F"
#                 },
#                 "rating": 4.2,
#                 "reference": "ChIJUezZyk2dwpQR1ZjJnd7AD1c",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 198,
#                 "vicinity": "R. Mariana Marqu\u00eas, 66 - Centro, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.7913347,
#                         "lng": -50.0077557
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.78999402010727,
#                             "lng": -50.00636957010728
#                         },
#                         "southwest": {
#                             "lat": -24.79269367989271,
#                             "lng": -50.00906922989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "79afacf023eb1ee928df545fff1fd5a767c37b04",
#                 "name": "Central Palace Hotel - Castro (PR)",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 960,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/113611644224940597398\">Hotel Central Palace</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA-d3MT60oXmAe7U_NQbgrteJP-EdxyJwby0-pEJ7I6R4CDniv9_CgXKENpNsCkIJ0oRiM0axM5NPZHceZ2fHralij-eAXE_UenEQvPzR57ZHTtWQixccBrGZ0x-D_wGl5EhB0W6c6iwMeTJMcb4lR_wZDGhQyF2ysJcHqyvBf___9F_20RL0v0w",
#                         "width": 1280
#                     }
#                 ],
#                 "place_id": "ChIJP4uJvU2dwpQRi-9oeVlg6ng",
#                 "plus_code": {
#                     "compound_code": "6X5R+FV Centro, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F6X5R+FV"
#                 },
#                 "rating": 4.1,
#                 "reference": "ChIJP4uJvU2dwpQRi-9oeVlg6ng",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 386,
#                 "vicinity": "R. Cipriano Marqu\u00eas de Souza, 18 - Centro, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.7897222,
#                         "lng": -50.0063889
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.78835717010728,
#                             "lng": -50.00510757010728
#                         },
#                         "southwest": {
#                             "lat": -24.79105682989272,
#                             "lng": -50.00780722989273
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "476248ddce19e40a3a18cd9837b36cd85c311b59",
#                 "name": "Buganville Palace Hotel",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 2592,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/102296162961275136395\">ken ito</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAIFLVl5UEcoNSOinttAKvEnZhcll1DOffGMJQKcPxNjZfL8XbKLYEVysoRp-EXfpHdFHiXBRMiz2gSLrG-LZNsf8gjRyjxpF_zX4XLD8WwLCbSGfngNpspdcgupUUUVleEhDsq6nOU5sx18RI9fLbWxXHGhS84LVA4RIDnaHmh_-P2JiihxwHBg",
#                         "width": 4608
#                     }
#                 ],
#                 "place_id": "ChIJ627zz1OdwpQRoewwaxB-L0w",
#                 "plus_code": {
#                     "compound_code": "6X6V+4C Centro, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F6X6V+4C"
#                 },
#                 "rating": 4.4,
#                 "reference": "ChIJ627zz1OdwpQRoewwaxB-L0w",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 465,
#                 "vicinity": "Pra\u00e7a Manoel Ribas, 99 - Centro, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.8033628,
#                         "lng": -50.01184989999999
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.80204212010728,
#                             "lng": -50.01048692010728
#                         },
#                         "southwest": {
#                             "lat": -24.80474177989272,
#                             "lng": -50.01318657989273
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "0d39a8c7c8f984e827e597c8ea556b4ed40f98c8",
#                 "name": "Urano Business Hotel",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 846,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/116696959554679120379\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAS3nRWlpD-v1cl39DKBBBCyH96NQ8J0rB_LABJ3UbYppOLwf-pFdi6B6ZInBnw6TLuNaPS59lb5W3gdSCZksgcPuYVkA9VcIN-c7H_HC4ZxdLZoBUq8yY84bhLP0hzRYPEhAx62t-K3OspMSgSHZx3cgzGhSD43bcY5Xk9oe7IrA8ymyHugcC5A",
#                         "width": 1270
#                     }
#                 ],
#                 "place_id": "ChIJi9dEocKdwpQRUff0guVU4C0",
#                 "plus_code": {
#                     "compound_code": "5XWQ+M7 Vila Frei Mathias, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F5XWQ+M7"
#                 },
#                 "rating": 4.5,
#                 "reference": "ChIJi9dEocKdwpQRUff0guVU4C0",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 69,
#                 "vicinity": "R. Jos\u00e9 Marques, 26 - Vila Frei Mathias, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.7914731,
#                         "lng": -50.0080458
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.79016142010728,
#                             "lng": -50.00654467010727
#                         },
#                         "southwest": {
#                             "lat": -24.79286107989272,
#                             "lng": -50.00924432989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "b870274ffd06421e6b64af45dc1660dee636e6ee",
#                 "name": "OYO Grande Hotel",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 1920,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/102769961985143012423\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAgbYNTOrdmRKiBdOo4RWWfayzmQ0mMPfmrC9ouS1jUvbOimwRLnot7YgBuq-3vwqC6-WEY63c07jjbb87pk3qQ89febDkIDRsKKmSYGgsQMBx3B4Ls-u6vw7y3bQTtvzAEhBJEtfsICaDq0hIriCu_SMPGhToQxzhCAMxQTPQv8Tw-Rd32Rrj4A",
#                         "width": 2880
#                     }
#                 ],
#                 "place_id": "ChIJsxDClU2dwpQRChZOS33Zup0",
#                 "plus_code": {
#                     "compound_code": "6X5R+CQ Centro, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F6X5R+CQ"
#                 },
#                 "rating": 3.7,
#                 "reference": "ChIJsxDClU2dwpQRChZOS33Zup0",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 82,
#                 "vicinity": "R. Cipriano Marqu\u00eas de Souza, 44 - Centro, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.7840264,
#                         "lng": -50.00596909999999
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.78269817010728,
#                             "lng": -50.00457972010727
#                         },
#                         "southwest": {
#                             "lat": -24.78539782989272,
#                             "lng": -50.00727937989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "9d16836b32c856a7e04ddc533451306e4b921321",
#                 "name": "Pousada Rota Dos Tropeiros",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 2096,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/114760157127803595599\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA6MzMGIWt5YpiuSCR5z9hN_nmto41IdBz86m2qhImQjzE1p-RwdPHHL9fDKAoOFpf4Zs22uhRRnu1JXwYu1bxIBUo83U1gW2Wb_u-9DNU8-nzuCFaYejO2c9-l9ojbiqNEhAaSx4WKcg9CK3B6ZZl7eZfGhRb9rWPBgPVAN5ySHc8Mq3X1IOu-A",
#                         "width": 3724
#                     }
#                 ],
#                 "place_id": "ChIJv36osoaDwpQR2LmnKEDX72g",
#                 "plus_code": {
#                     "compound_code": "6X8V+9J Centro, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F6X8V+9J"
#                 },
#                 "rating": 4.5,
#                 "reference": "ChIJv36osoaDwpQR2LmnKEDX72g",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 148,
#                 "vicinity": "R. Pedro Kaled, 82 - Centro, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.8050327,
#                         "lng": -49.9962692
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.80368347010727,
#                             "lng": -49.99498122010728
#                         },
#                         "southwest": {
#                             "lat": -24.80638312989272,
#                             "lng": -49.99768087989273
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "57d9ffb49c29f851f9e94e3c8b73f9b07d8c9a50",
#                 "name": "Hotel e Restaurante Contorno Sul",
#                 "photos": [
#                     {
#                         "height": 3096,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/117622716361318052501\">Wellinton Maia Polopes</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA_PPTJjWZeNNxqp4KRh1srNz33eGMu_xtJB2Sv8Ps5TxHesBU4973NGhF-xyYyWPYIo5khsxfz-eJdcvy4iNlFh8Ua8mtePMqfwzkvwD-LEmWO9Khlpn7QZWtGEqpVoxfEhAye7QWzhSzoo914oF6t6vtGhTWYmkHeITld3s7-W6Y1c5YRtCRZg",
#                         "width": 4128
#                     }
#                 ],
#                 "place_id": "ChIJBSdMAhWdwpQRHTRhVxVWmRU",
#                 "plus_code": {
#                     "compound_code": "52V3+XF Jardim das Araucarias, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587G52V3+XF"
#                 },
#                 "rating": 4,
#                 "reference": "ChIJBSdMAhWdwpQRHTRhVxVWmRU",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 314,
#                 "vicinity": "R. Moacir El\u00edas Fadel, 415 - Jardim das Araucarias, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.7892901,
#                         "lng": -50.0173322
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.78788907010727,
#                             "lng": -50.01602517010728
#                         },
#                         "southwest": {
#                             "lat": -24.79058872989272,
#                             "lng": -50.01872482989273
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "55b89194389b8956b392df96b3a4a66e8dfecd8b",
#                 "name": "Pousada Bela Vista",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 1280,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/111413460502211540684\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAxwGOUAXIe6qA25OG3ASKAe8KX7YsMZb_iWhlupzoYs7Q_lUpQ6Cy_zKXy96w1ydWAxbcrklW1h73Jt3s6l9040PaNCoacByjM-KUZH-afvsp8Pzmw7797wMhMdinFdm4EhCCI7i89TLKgoFIk7W1uRx6GhRrJ-ZmofnvLtMwvHeuG1fWVXpyMg",
#                         "width": 720
#                     }
#                 ],
#                 "place_id": "ChIJ5y5ayKqCwpQRzPbIsr3LFdw",
#                 "plus_code": {
#                     "compound_code": "6X6M+73 Centro, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F6X6M+73"
#                 },
#                 "rating": 4.4,
#                 "reference": "ChIJ5y5ayKqCwpQRzPbIsr3LFdw",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 44,
#                 "vicinity": "R. Maestro Benedito Pereira, 1217 - Centro, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.7807113,
#                         "lng": -49.98682830000001
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.77934727010728,
#                             "lng": -49.98548122010728
#                         },
#                         "southwest": {
#                             "lat": -24.78204692989272,
#                             "lng": -49.98818087989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "ba8742d7e8067584ddcf34114fffbb8894b78d62",
#                 "name": "CHACARA BAILLY",
#                 "opening_hours": {
#                     "open_now": false
#                 },
#                 "photos": [
#                     {
#                         "height": 960,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/106281163871812624561\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAWBFdVHXbvmYGxQe1GDcliLl_TiHW-v-DKKPLqqjW2itIRpvHTBd84JprrBSvIdFuKmdFihHSK6vbKzfwyaayIBD5Es3nUJ54-9VzfSGHeqssP67l5HyKYfClmK2FkfvKEhBsqRSUCCO-5r--Il5e054SGhSh-5RsDfOlV2OrU7KRJOGryGvnow",
#                         "width": 1280
#                     }
#                 ],
#                 "place_id": "ChIJrWXORy2dwpQRhR-F4Q1MJdg",
#                 "plus_code": {
#                     "compound_code": "6297+P7 Jardim das Nacoes, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587G6297+P7"
#                 },
#                 "rating": 4.1,
#                 "reference": "ChIJrWXORy2dwpQRhR-F4Q1MJdg",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 36,
#                 "vicinity": "R. Matilde Baer, 527 - Jardim das Nacoes, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.8055456,
#                         "lng": -50.002877
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.80431707010728,
#                             "lng": -50.00154967010727
#                         },
#                         "southwest": {
#                             "lat": -24.80701672989272,
#                             "lng": -50.00424932989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "0958bcd3f1858b2f610c34d1a6a67c1c0afe0ce9",
#                 "name": "Hotel D'Lucas",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 2592,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/115083540204274345045\">Lucas Marcondes</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA-MHAtz31Ht685GKeG-zdHK4bcK_DqEIe4R8rD5528GcHZqcvYel9xlNvp2K2KwtZXfJ6Uw_cUI73_VAr4JiDR52vSN9Z-N_gLSvJVV5sEvtFOuLptdsqEQB39lsUOrH5EhB7RUvIcKbVDEVedWu7T4XfGhQCj9oo7fsQJKwaUg0-VIUpUCrLww",
#                         "width": 4608
#                     }
#                 ],
#                 "place_id": "ChIJZdXVGmqdwpQR2GrpefKpPc0",
#                 "plus_code": {
#                     "compound_code": "5XVW+QR Jardim Colonial, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F5XVW+QR"
#                 },
#                 "rating": 3.8,
#                 "reference": "ChIJZdXVGmqdwpQR2GrpefKpPc0",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 40,
#                 "vicinity": "Av. Pref. Ronie Cardoso, 951 - Jardim Colonial, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.8068516,
#                         "lng": -49.9909305
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.80555837010728,
#                             "lng": -49.98960082010728
#                         },
#                         "southwest": {
#                             "lat": -24.80825802989272,
#                             "lng": -49.99230047989273
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "c7a34af03c40392d6bbee8e451df2a555aaad0dd",
#                 "name": "Hotel Alvorada",
#                 "photos": [
#                     {
#                         "height": 3120,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/112999117142231622219\">Adriano Aparecido Alves</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAsypkVOnLLrB1JrU5KKUabFDNqDUcZ7uV0iFZhut3oj2UztDA25ehkAdKDYIRPX9rMEYyHzRKPtCosU25ZfUKgDUX4VhkfEnliHMLHN-lR68ULULuoujQYHJBUVtzjUluEhCX4usDbolFIGjUkCXnLyCVGhTLNR1z7K1fnk285LlpY5sE_2zj6A",
#                         "width": 4160
#                     }
#                 ],
#                 "place_id": "ChIJ627zz1OdwpQRHRNEtBsXYWY",
#                 "plus_code": {
#                     "compound_code": "52V5+7J Jardim Social Arapongas, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587G52V5+7J"
#                 },
#                 "rating": 3.8,
#                 "reference": "ChIJ627zz1OdwpQRHRNEtBsXYWY",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 173,
#                 "vicinity": "R. Gen\u00e9sio Ara\u00fajo Barbosa, 297 - Jardim Social Arapongas, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.794943,
#                         "lng": -50.00875
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.79359642010727,
#                             "lng": -50.00738672010728
#                         },
#                         "southwest": {
#                             "lat": -24.79629607989272,
#                             "lng": -50.01008637989273
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "2d13d58795005115fbb24332fda1c334c3f2c7d8",
#                 "name": "OYO Grande Hotel",
#                 "place_id": "ChIJsQHdKFCdwpQRmAbF0SiD2o8",
#                 "plus_code": {
#                     "compound_code": "6X4R+2G Centro, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587F6X4R+2G"
#                 },
#                 "rating": 0,
#                 "reference": "ChIJsQHdKFCdwpQRmAbF0SiD2o8",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 0,
#                 "vicinity": "R. Cipriano Marqu\u00eas de Souza, 442 - Centro, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.804162,
#                         "lng": -49.9939678
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.80280932010728,
#                             "lng": -49.99255377010728
#                         },
#                         "southwest": {
#                             "lat": -24.80550897989272,
#                             "lng": -49.99525342989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "05904366159d01f76df932983a2667281f93291b",
#                 "name": "Hotel S\u00e3o Carlos",
#                 "place_id": "ChIJgTH-A3OdwpQR9hjikJdPvF8",
#                 "plus_code": {
#                     "compound_code": "52W4+8C Vila Rio Branco, Castro - State of Paran\u00e1, Brazil",
#                     "global_code": "587G52W4+8C"
#                 },
#                 "rating": 5,
#                 "reference": "ChIJgTH-A3OdwpQR9hjikJdPvF8",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 1,
#                 "vicinity": "Rua Dr. Javert Madureira, 1680 - Vila Rio Branco, Castro"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": -24.8356867,
#                         "lng": -50.024648
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": -24.83433742010728,
#                             "lng": -50.02329677010728
#                         },
#                         "southwest": {
#                             "lat": -24.83703707989272,
#                             "lng": -50.02599642989272
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "21fd252bb3902ccc8f5041c9e8d6fd61379a7d85",
#                 "name": "Motel Dallas",
#                 "photos": [
#                     {
#                         "height": 4608,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/102053314427147578797\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAxrcG4n_7_lOCDGtC4ve4dM3BI3ynZ2QaC3W2vuyidGZOAt2WHcObNpjs5wmyhH8i-MWQJFgUEonWDJoZmckKuvhOSX5n9cUcSD4IOnCSI6DBxJmTQbwiYZC7dEPVK3x-EhDg_ZHj7uUxGFvd9LS6cK_DGhQPYx0Mbj7M-LdxQboAHGsJsdENuA",
#                         "width": 3456
#                     }
#                 ],
#                 "place_id": "ChIJfWXjbXsn6JQRNJY8hwIQ6-w",
#                 "plus_code": {
#                     "compound_code": "5X7G+P4 Castro, State of Paran\u00e1, Brazil",
#                     "global_code": "587F5X7G+P4"
#                 },
#                 "rating": 3.5,
#                 "reference": "ChIJfWXjbXsn6JQRNJY8hwIQ6-w",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 41,
#                 "vicinity": "Castro"
#             }
#         ],
#         "status": "OK"
#     },
#     {
#         "html_attributions": [],
#         "results": [
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 27.7043744,
#                         "lng": 81.93478619999999
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 27.70573412989272,
#                             "lng": 81.93614407989273
#                         },
#                         "southwest": {
#                             "lat": 27.70303447010728,
#                             "lng": 81.93344442010728
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "5800c089a59f51658060da8854a36337502a15a5",
#                 "name": "Faiz Computers And Madina Hotel",
#                 "opening_hours": {
#                     "open_now": false
#                 },
#                 "photos": [
#                     {
#                         "height": 1440,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/118060880607666954602\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAML53iFuMKnYa0e7Frwhwi1Qrb6o0KrktLM2HxVSZ0l-TeGtyK350ofkKbo38jIq7ItqvA7ksKoRri2VKSvDpIWuAdQ3dKzvjIIE5PLkjoorN2GE926jJ_XYH3hF2VuJ0EhCOiDO7z3888RDB7hnrzfy0GhQrHcR8QQq0Epx84Lox7AKomP0gbw",
#                         "width": 1080
#                     }
#                 ],
#                 "place_id": "ChIJE8JzHm01mDkR6_zVx03PqzI",
#                 "plus_code": {
#                     "compound_code": "PW3M+PW Bhinga, Uttar Pradesh, India",
#                     "global_code": "7MV3PW3M+PW"
#                 },
#                 "rating": 0,
#                 "reference": "ChIJE8JzHm01mDkR6_zVx03PqzI",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 0,
#                 "vicinity": "Near Mohammadi Masjid Bahraich Road, Pure Khairi Before Khairi Mod, Bhinga Distt"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 27.7082404,
#                         "lng": 81.93461359999999
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 27.70958567989272,
#                             "lng": 81.93598372989273
#                         },
#                         "southwest": {
#                             "lat": 27.70688602010728,
#                             "lng": 81.93328407010728
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "0d62fce8b7ddcc6be41c8ef08a9231cf4a675056",
#                 "name": "ANAND MISHTAN BHANDAR AND COFFEE TEA SETAL",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "place_id": "ChIJbUOk2b40mDkRk4ZMgNtHnZw",
#                 "plus_code": {
#                     "compound_code": "PW5M+7R Bhinga, Uttar Pradesh, India",
#                     "global_code": "7MV3PW5M+7R"
#                 },
#                 "rating": 4.6,
#                 "reference": "ChIJbUOk2b40mDkRk4ZMgNtHnZw",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 12,
#                 "vicinity": "Sirsiya, ROAD, Bhinga"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 27.7043744,
#                         "lng": 81.9347861
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 27.70573422989272,
#                             "lng": 81.93614397989272
#                         },
#                         "southwest": {
#                             "lat": 27.70303457010728,
#                             "lng": 81.93344432010728
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "327d4738c97611575c0730de19f2d05abb28f5cd",
#                 "name": "Adnan Apartment",
#                 "place_id": "ChIJa5Tsqbk0mDkRAycjIXe8GnA",
#                 "plus_code": {
#                     "compound_code": "PW3M+PW Bhinga, Uttar Pradesh, India",
#                     "global_code": "7MV3PW3M+PW"
#                 },
#                 "rating": 0,
#                 "reference": "ChIJa5Tsqbk0mDkRAycjIXe8GnA",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 0,
#                 "vicinity": "Bhinga"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 27.7020062,
#                         "lng": 81.93466860000001
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 27.70351502989272,
#                             "lng": 81.93606547989272
#                         },
#                         "southwest": {
#                             "lat": 27.70081537010728,
#                             "lng": 81.93336582010727
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "80f015ed047e75a636612186b480d05aed4157e2",
#                 "name": "Hina Lodge",
#                 "photos": [
#                     {
#                         "height": 2014,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/113501242079708905701\">akhilesh vishwakarma</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAY7UC5Oc7uR86aBtC-3eIynJcN8nJZcjhD3fzGu4jkqXulYHnvjaZ9unab0DchEM_UJ5x67iPlufB71IbGcXNkeyNdug2QNHZGHRP6hmj4FwjnRlnYrS7-zYL8pbSz7TAEhDKBpV80ojB9vrQJ1Qq8x-QGhSnONZErrOJ4QsQ1dMRie2kD8ujXA",
#                         "width": 906
#                     }
#                 ],
#                 "place_id": "ChIJ_bTD07k0mDkRX0a40Bwwfxc",
#                 "plus_code": {
#                     "compound_code": "PW2M+RV Bhinga, Uttar Pradesh, India",
#                     "global_code": "7MV3PW2M+RV"
#                 },
#                 "rating": 3.1,
#                 "reference": "ChIJ_bTD07k0mDkRX0a40Bwwfxc",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 53,
#                 "vicinity": "Bhinga"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 27.7037885,
#                         "lng": 81.93035189999999
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 27.70513687989272,
#                             "lng": 81.93170072989271
#                         },
#                         "southwest": {
#                             "lat": 27.70243722010728,
#                             "lng": 81.92900107010728
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#                 "id": "58156cba781fd0547e65b552ab4a1a5ba085ffdc",
#                 "name": "Yadav Hotel",
#                 "opening_hours": {
#                     "open_now": false
#                 },
#                 "photos": [
#                     {
#                         "height": 2752,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/107701522048317279234\">SHAILESH VISHWAKARMA</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAcJVzGavVECrqBmw8BKZ0w7sAWmde8N1neyJBhfanMKgoxX4j3in7EenpQbEB56zJBV2cXY0TBBeaq_6zY2r-inAebULZcvp8O-ycweZgIycLc-oR6IhiAiXSMOCaZo5aEhA3PZ4In7X3Q1RFvjt6QU2LGhTZ1wseGzfNv0WOcOOCcegNiPqUvg",
#                         "width": 1972
#                     }
#                 ],
#                 "place_id": "ChIJ7Qy6mMc0mDkRU2jZrLEc3Mw",
#                 "plus_code": {
#                     "compound_code": "PW3J+G4 Bhinga, Uttar Pradesh, India",
#                     "global_code": "7MV3PW3J+G4"
#                 },
#                 "rating": 2.9,
#                 "reference": "ChIJ7Qy6mMc0mDkRU2jZrLEc3Mw",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "restaurant",
#                     "food",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 10,
#                 "vicinity": "Ikauna-Bhinga Sampark Marg, Bhinga"
#             }
#         ],
#         "status": "OK"
#     },
#     {
#         "html_attributions": [],
#         "results": [
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 25.5297338,
#                         "lng": 73.9084139
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 25.53114047989272,
#                             "lng": 73.90977847989272
#                         },
#                         "southwest": {
#                             "lat": 25.52844082010728,
#                             "lng": 73.90707882010727
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "27e86a53c6f1cf0e97f6bbc2cecd7aed8ce440ad",
#                 "name": "Deogarh Mahal",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 330,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/115289434149295789472\">Deogarh Mahal</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAzoTrYR0lYTdiITnstQ_NaI2-wFKggv_FP409SaTe_UJlCbT5nbnco2rl9lhtJ88Ut57Grh4NF5pDPTojLIt7EQzYLsrxsU9hayFuBOW3TA4dWkl_IdH6pdDvfVW3b0FzEhCX_CjUnekqZxxrGQUs2noMGhQbfBQJ110yJFlLHp4tG0ZQDBN7Ng",
#                         "width": 1170
#                     }
#                 ],
#                 "place_id": "ChIJmTtvnnFraDkRaredGl7p5FA",
#                 "plus_code": {
#                     "compound_code": "GWH5+V9 Deogarh, Rajasthan, India",
#                     "global_code": "7JQMGWH5+V9"
#                 },
#                 "rating": 4.3,
#                 "reference": "ChIJmTtvnnFraDkRaredGl7p5FA",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 1093,
#                 "vicinity": "Palace Rd, Deogarh"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 25.525058,
#                         "lng": 73.90972049999999
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 25.52643352989272,
#                             "lng": 73.91122407989272
#                         },
#                         "southwest": {
#                             "lat": 25.52373387010728,
#                             "lng": 73.90852442010728
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "f71c3f919e073da54b2edd38a7d34d115cbc42b8",
#                 "name": "Dev Shree Relais and Ch\u00e2teaux Luxury Hotel Deogarh",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 600,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/102917957279692008866\">Dev Shree</a>"
#                         ],
#                         "photo_reference": "CmRaAAAALxiQSKLGwDKhND_7GCiyYET8Bb2HZqvSmKbNf1T_u4e3lrsLp0kbz9wQ6assauT3IKQhzvIWEPbQ8ZDb37UkB4NfRU0RQmI12-pcZfEtIcoRxFJkQGw7B-3u3na9A5M2EhBlFH2jeoWUfiHuMMphX8pAGhQATUUUVFr2-UEdd91hwJlv_1SXeg",
#                         "width": 800
#                     }
#                 ],
#                 "place_id": "ChIJQ9HmmMm0aTkRl-KvS7LHrx0",
#                 "plus_code": {
#                     "compound_code": "GWG5+2V Deogarh, Rajasthan, India",
#                     "global_code": "7JQMGWG5+2V"
#                 },
#                 "rating": 4.5,
#                 "reference": "ChIJQ9HmmMm0aTkRl-KvS7LHrx0",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 125,
#                 "vicinity": "Palla Bagh, Deogarh"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 25.5468223,
#                         "lng": 73.8741431
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 25.54819532989272,
#                             "lng": 73.87546652989272
#                         },
#                         "southwest": {
#                             "lat": 25.54549567010728,
#                             "lng": 73.87276687010727
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "4dee68d9a23998e37e87eb337ad5dde3cfc2c7d3",
#                 "name": "Ishwar Nain Hotel",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 1960,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/100075235579892895878\">pradeep narwani</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA8dNNUGtKSPA-rDrbxc7NjmuCEk-mhVVKRogrZEBSRoXyYcgeD1NvdxD7skdxRlzUaw20whkta8NjoyLaaExqG5-jekO3Yurivz50Qoek27xJFYrTHRFBJQ7cxnnIYXxZEhByRXIKUo6wJTEWm50NKxqbGhSTK3J66BAabK8tsBWlI2BPAUhDLg",
#                         "width": 4032
#                     }
#                 ],
#                 "place_id": "ChIJP5j7shG1aTkRjSVzupO-Abo",
#                 "plus_code": {
#                     "compound_code": "GVWF+PM Deogarh, Rajasthan, India",
#                     "global_code": "7JQMGVWF+PM"
#                 },
#                 "rating": 4,
#                 "reference": "ChIJP5j7shG1aTkRjSVzupO-Abo",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 47,
#                 "vicinity": "NH8, Kamlighat Choraha, Deogarh kamlighat Choraha, Deogarh"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 25.5284591,
#                         "lng": 73.92565239999999
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 25.52949402989272,
#                             "lng": 73.92693977989272
#                         },
#                         "southwest": {
#                             "lat": 25.52679437010728,
#                             "lng": 73.92424012010729
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "a3aa900058be17dd74614f83b2054efd25ff63af",
#                 "name": "Barabagh Deogarh",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 652,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/100974045871499593159\">Arpit Acharya</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAhIt7n2ftioGVjTjo0fZduZclAYzpqSALoYnULHd4jotEX4uaZwPTPicCnmqUaWd8amBS3zICq7YZeWZhGyOUGFk2Y4Wxu5NAZTUnE249poHLbzOYqTRWpf1UwbYWd0qdEhBNKqa6ccp1nWw7oZLxSqTdGhRPQh8ToxzZ8RnJ3hnvGisVWJ3W0A",
#                         "width": 1029
#                     }
#                 ],
#                 "place_id": "ChIJBwMISq60aTkRoa2pieZU_wY",
#                 "plus_code": {
#                     "compound_code": "GWHG+97 Deogarh, Rajasthan, India",
#                     "global_code": "7JQMGWHG+97"
#                 },
#                 "rating": 4.3,
#                 "reference": "ChIJBwMISq60aTkRoa2pieZU_wY",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 40,
#                 "vicinity": "Dist :, Barabagh, Near Lasani Churaha, Bhilwara Rd, Deogarh"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 25.492076,
#                         "lng": 73.927014
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 25.49403087989272,
#                             "lng": 73.92934979999998
#                         },
#                         "southwest": {
#                             "lat": 25.49133122010728,
#                             "lng": 73.92623540000002
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "8e6bb26a65b806730880c197a04901fca95cc5b6",
#                 "name": "Seengh Sagar Fort",
#                 "photos": [
# ...
#                         },
#                         "southwest": {
#                             "lat": 26.02342762010728,
#                             "lng": 89.98042427010728
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "6fbc5092aff3547a093f6938c1191b6e3cba62fe",
#                 "name": "Samrat Hotel and Lodge",
#                 "photos": [
#                     {
#                         "height": 1440,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/101849135951020512679\">TAZA News</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA6tjp8q052S9K1OZKr-8Lb0eVQg4yS8WwpM03wRpkm4NaiOsR9GruulT6BI9YsiIeYShZzPRaK1WlD-daOHWbj3Fj9x2rJHGQyARkEyUNW7iRazAfyD_Eawq-iJFX3EXxEhD3P9ZFjCyWEVc-XA7J9gXjGhQ41eP_KX2H4jWia3NBGEMXxfRg2Q",
#                         "width": 2560
#                     }
#                 ],
#                 "place_id": "ChIJ3VV-GRag4jkRD4RB06LBzJU",
#                 "plus_code": {
#                     "compound_code": "2XFJ+WP Dhubri, Assam, India",
#                     "global_code": "7MRF2XFJ+WP"
#                 },
#                 "rating": 3.5,
#                 "reference": "ChIJ3VV-GRag4jkRD4RB06LBzJU",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 329,
#                 "vicinity": "GTB Road, Ward Number 9, Bidyapara, Dhubri"
#             }
#         ],
#         "status": "OK"
#     },
#     {
#         "html_attributions": [],
#         "results": [
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 16.3345029,
#                         "lng": 119.7906049
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 16.33582712989272,
#                             "lng": 119.7919968298927
#                         },
#                         "southwest": {
#                             "lat": 16.33312747010728,
#                             "lng": 119.7892971701073
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "bb204facdefdc32cc49dc34ed7d2247ed93f17c8",
#                 "name": "Traditional Filipino Villa",
#                 "photos": [
#                     {
#                         "height": 1908,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/101953039677871482445\">Udo Flagner</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA9HoGfuyWF-dbCNcEtdd913uMJ5HAkNIHUbep8-S54MWVUIdvx8EkRLdF3E4aus45fMSDtA56Nn81wH0SzYg0AXXnajFyIky4uyP6Fzdm0YXZqk4od7grYrSZyUpbqSpAEhCTaoHqMl4HYqjUxx44XhO9GhTfLeKoEjJaFIxhSEFTyVktofSrww",
#                         "width": 4032
#                     }
#                 ],
#                 "place_id": "ChIJ6SDoPCrIkzMR8yBggFlYG4g",
#                 "plus_code": {
#                     "compound_code": "8QMR+R6 Bolinao, Pangasinan, Philippines",
#                     "global_code": "7P8X8QMR+R6"
#                 },
#                 "rating": 4.5,
#                 "reference": "ChIJ6SDoPCrIkzMR8yBggFlYG4g",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 6,
#                 "vicinity": "Bolinao"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 16.335323,
#                         "lng": 119.7909291
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 16.33659397989272,
#                             "lng": 119.7924138798927
#                         },
#                         "southwest": {
#                             "lat": 16.33389432010728,
#                             "lng": 119.7897142201073
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "6f8c64cf9eb99d64e0d7017d76114bb16173531d",
#                 "name": "Casa Estrella Beach Resort",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "place_id": "ChIJb8MubPDJkzMRl3oi8QfcKWE",
#                 "plus_code": {
#                     "compound_code": "8QPR+49 Bolinao, Pangasinan, Philippines",
#                     "global_code": "7P8X8QPR+49"
#                 },
#                 "rating": 5,
#                 "reference": "ChIJb8MubPDJkzMRl3oi8QfcKWE",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 1,
#                 "vicinity": "Bolinao"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 16.303941,
#                         "lng": 119.782327
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 16.30529422989272,
#                             "lng": 119.7836628298927
#                         },
#                         "southwest": {
#                             "lat": 16.30259457010728,
#                             "lng": 119.7809631701073
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "94472e3252e4580c5a30970e75088249dcebbb3f",
#                 "name": "KNB WEST VILLA INN",
#                 "opening_hours": {
#                     "open_now": true
#                 },
#                 "photos": [
#                     {
#                         "height": 540,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/100373833701580805934\">Patar Bolinao Inn (la parola de bolinao beach resort annex)</a>"
#                         ],
#                         "photo_reference": "CmRaAAAADArZkB2IU9TLG0onifCUHI5aB0s9wMB8sJMqP6SCfk--vmm3ym36Fz4idoO6p9LU6giE9KLx5z1ALaiFbqz_ZfgJBgZAGhiqm8MlmjE36f_U0Q7euddn4_GAs1bVPZj_EhBcO1-Z0Bwt5VK0y8onbTg2GhTtb7Y9IggCLuznFpe83FaVRDEYzQ",
#                         "width": 720
#                     }
#                 ],
#                 "place_id": "ChIJcywT8vu3kzMR1ip-E5j9_ug",
#                 "plus_code": {
#                     "compound_code": "8Q3J+HW Bolinao, Pangasinan, Philippines",
#                     "global_code": "7P8X8Q3J+HW"
#                 },
#                 "rating": 4.2,
#                 "reference": "ChIJcywT8vu3kzMR1ip-E5j9_ug",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 9,
#                 "vicinity": "Patar Rd, Bolinao"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 16.3026729,
#                         "lng": 119.7809888
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 16.30368717989272,
#                             "lng": 119.7824521298927
#                         },
#                         "southwest": {
#                             "lat": 16.30098752010728,
#                             "lng": 119.7797524701073
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "6efe30946b962bbb14af28ffbd0bb123d709673b",
#                 "name": "Patar Beach Resort",
#                 "photos": [
#                     {
#                         "height": 3456,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/107554491456349583656\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAQhdx0ow1B5kB6iVl86Xr9J-F0qB1o7OUcw4rf2Bzt5mSWHdVI8LS28Vkawv_6UTlNJhn38kN_VTgg8wzDyUbqTqYKXDekxoRAXDvCYofONrSuEMAAPXQ5Thn8WVERPqMEhADca0Kxpo79eh9FQYKRK0aGhR3RZh1ltzkqMsfV1u-61VJFB4TCA",
#                         "width": 4608
#                     }
#                 ],
#                 "place_id": "ChIJY64ubvm3kzMRF5yz6OumB2A",
#                 "plus_code": {
#                     "compound_code": "8Q3J+39 Bolinao, Pangasinan, Philippines",
#                     "global_code": "7P8X8Q3J+39"
#                 },
#                 "rating": 4.4,
#                 "reference": "ChIJY64ubvm3kzMRF5yz6OumB2A",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 225,
#                 "vicinity": "Bolinao"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 16.297853,
#                         "lng": 119.78003
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 16.29908477989272,
#                             "lng": 119.7815971298927
#                         },
#                         "southwest": {
#                             "lat": 16.29638512010727,
#                             "lng": 119.7788974701073
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "d5e04b38ceac954e9170b45471112f4937519a74",
#                 "name": "Hotel G Beach Resort and Restobar",
#                 "photos": [
#                     {
#                         "height": 3120,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/110271467682865092474\">Kerth Alfonso</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAjNOdcZARWPyzym8HIeQqs4QeoHaQLkhTeFRYAhLsgSmtDmPoLmFU5WOBcJsFSlaArxiSEHVunvwIMnxExxrwB4PE9NzslgGgWng47ZStXH7shX_VxKFKkJBl5G44IXa_EhBT01rn0egmprXLAzLtVeNjGhQ8p8yYIfJQrgvRYHAJpnDb6f0dTg",
#                         "width": 4160
#                     }
#                 ],
#                 "place_id": "ChIJcbtRhgK4kzMRhF_on7JGSz0",
#                 "plus_code": {
#                     "compound_code": "7QXJ+42 Bolinao, Pangasinan, Philippines",
#                     "global_code": "7P8X7QXJ+42"
#                 },
#                 "rating": 5,
#                 "reference": "ChIJcbtRhgK4kzMRhF_on7JGSz0",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 2,
#                 "vicinity": "Sitio Abrac, Bolinao"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 16.29694,
#                         "lng": 119.7801214
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 16.29862827989272,
#                             "lng": 119.7816448298927
#                         },
#                         "southwest": {
#                             "lat": 16.29592862010728,
#                             "lng": 119.7789451701073
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "a4bd7eaac76baf5ea391c22a8d2647d6fffe12cd",
#                 "name": "Veue Beach Cabins",
#                 "opening_hours": {
#                     "open_now": false
#                 },
#                 "photos": [
#                     {
#                         "height": 500,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/116970933802926526710\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAA52gr77rq3HQCzLkaUWkbyRNoUnfkJ6OONVC48lA8gCCK829sUYRxoFvHc20QODsWLs6r6cNVFX8g5K5ZQoQvxbtrdkPIqkS-IMOazUiJOacFCoYJGofv7ThbHNA8-RjVEhA90whv-2WfdmQuK4IKTgBgGhSLa1mApTbGKHKZb3PTJZIr2N-7rg",
#                         "width": 750
#                     }
#                 ],
#                 "place_id": "ChIJW5MdiQK4kzMRsADdDKTsEaI",
#                 "plus_code": {
#                     "compound_code": "7QWJ+Q2 Bolinao, Pangasinan, Philippines",
#                     "global_code": "7P8X7QWJ+Q2"
#                 },
#                 "rating": 4.5,
#                 "reference": "ChIJW5MdiQK4kzMRsADdDKTsEaI",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "real_estate_agency",
#                     "travel_agency",
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 35,
#                 "vicinity": "VEUE Beach Cabins Sitio Abrac, Quintos Rd, Bolinao"
#             },
#             {
#                 "geometry": {
#                     "location": {
#                         "lat": 16.3060668,
#                         "lng": 119.7810864
#                     },
#                     "viewport": {
#                         "northeast": {
#                             "lat": 16.30719667989272,
#                             "lng": 119.7825176298927
#                         },
#                         "southwest": {
#                             "lat": 16.30449702010728,
#                             "lng": 119.7798179701073
#                         }
#                     }
#                 },
#                 "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#                 "id": "dfcc55545bfa0bdcae82fcc5b50fe4ba9f768d38",
#                 "name": "Treasures of Bolinao Beach Resort",
#                 "opening_hours": {
#                     "open_now": false
#                 },
#                 "photos": [
#                     {
#                         "height": 3361,
#                         "html_attributions": [
#                             "<a href=\"https://maps.google.com/maps/contrib/115283681931225028668\">A Google User</a>"
#                         ],
#                         "photo_reference": "CmRaAAAAVA1kKKjZJp1p2bAcpRy8Vyyu0YCYcEAJ4_DnKhO5bEqLPQjjjru0gTEQJWMSVh4kW2JNjSwWuKBIPpJT9_kBCfb2L12RlwZw38-PjsjmYAPNtgAfWR-UsBXvProzm1woEhCPfRQZe_TIYrB6YcYu9UmZGhQsj2Mxy86zCvio0Bb6AnMKGkwlYw",
#                         "width": 5042
#                     }
#                 ],
#                 "place_id": "ChIJJX0YX83OkzMR5mtz9fkY924",
#                 "plus_code": {
#                     "compound_code": "8Q4J+CC Bolinao, Pangasinan, Philippines",
#                     "global_code": "7P8X8Q4J+CC"
#                 },
#                 "rating": 3.8,
#                 "reference": "ChIJJX0YX83OkzMR5mtz9fkY924",
#                 "scope": "GOOGLE",
#                 "types": [
#                     "lodging",
#                     "point_of_interest",
#                     "establishment"
#                 ],
#                 "user_ratings_total": 283,
#                 "vicinity": "Cape Beach Cres, Bolinao"
#             }
#         ],
#         "status": "OK"
#     }
# ]

# %%
# convert response to json
#places_data = response.json()

# Print the name and address of the first restaurant that appears
print(response_json["results"][0]["name"])
print(response_json["results"][0]["vicinity"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-c2eb60a9f931> in <module>
#       3
#       4 # Print the name and address of the first restaurant that appears
# ----> 5 print(response_json["results"][0]["name"])
#       6 print(response_json["results"][0]["vicinity"])
#
# TypeError: list indices must be integers or slices, not str

# %%
locations = city_data[["Latitude", "Longitude"]]
humidity = city_data["Humidity"]

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, 
                                 max_intensity=10, point_radius=1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = clear_skys[["Latitude", "Longitude"]]
humidity = clear_skys["Humidity"]

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, 
                                 max_intensity=10, point_radius=1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
